# %% [markdown]
# # REGCOIL
# This example reproduces REGCOIL results, and performs a Taylor test
# that compares QUADCOIL derivatives with the results yielded by
# finite-differencing many REGCOIL results.
#
# This notebook requires the regcoil branch of simsopt for running
# REGCOIL and loading data. QUADCOIL itself does not depend on
# Simsopt or REGCOIL.

# %%
import unittest
from quadcoil.quantity import winding_surface_B, Bnormal, f_B, f_K, K, K2
from quadcoil.quantity.current import _f_K, _K, _K2
from quadcoil import gen_winding_surface_arc, quadcoil
import jax.numpy as jnp
from jax import eval_shape

# %% [raw]
# from load_test_data import load_data, compare
# winding_surface, plasma_surface, cp, cpst, qp = load_data()

# %% [raw]
# f_K(qp, {'phi': cp.get_dofs()})

# %% [raw]
# jnp.save('test_data', {
#     'nfp': cp.nfp,
#     'stellsym': cp.stellsym,
#     'mpol': cp.mpol,
#     'ntor': cp.ntor,
#     'plasma_dofs': cpst.plasma_surface.get_dofs(),
#     'plasma_mpol': cpst.plasma_surface.mpol,
#     'plasma_ntor': cpst.plasma_surface.ntor,
#     'net_poloidal_current_amperes': cp.net_poloidal_current_amperes,
#     'net_toroidal_current_amperes': cp.net_toroidal_current_amperes,
#     'plasma_coil_distance': plasma_surface.minor_radius(),
#     'metric_name': ('f_B', 'f_K'),
#     'verbose': 3,
# })

# %%
data_dict = jnp.load('test_data.npy', allow_pickle=True).item()
nfp = data_dict['nfp']
stellsym = data_dict['stellsym']
mpol = data_dict['mpol']
ntor = data_dict['ntor']
plasma_dofs = data_dict['plasma_dofs']
plasma_mpol = data_dict['plasma_mpol']
plasma_ntor = data_dict['plasma_ntor']
net_poloidal_current_amperes = data_dict['net_poloidal_current_amperes']
net_toroidal_current_amperes = data_dict['net_toroidal_current_amperes']
plasma_coil_distance = data_dict['plasma_coil_distance']
metric_name = data_dict['metric_name']
verbose = data_dict['verbose']

# %% [raw]
# # nescoil_out_dict, nescoil_qp, nescoil_phi_mn, _ =
# quadcoil(
#     nfp=cp.nfp,
#     stellsym=cp.stellsym,
#     mpol=cp.mpol,
#     ntor=cp.ntor,
#     plasma_dofs=cpst.plasma_surface.get_dofs(),
#     plasma_mpol=cpst.plasma_surface.mpol,
#     plasma_ntor=cpst.plasma_surface.ntor,
#     net_poloidal_current_amperes=cp.net_poloidal_current_amperes,
#     net_toroidal_current_amperes=cp.net_toroidal_current_amperes,
#     # plasma_coil_distance=plasma_surface.minor_radius(),
#     winding_dofs = winding_surface.get_dofs(),
#     winding_mpol = winding_surface.mpol,
#     winding_ntor = winding_surface.ntor,
#     metric_name=('f_B', 'f_K'),
#     verbose=3,
# )

# %%
# nescoil_out_dict, nescoil_qp, nescoil_phi_mn, _ = 
quadcoil(
    nfp=nfp,
    stellsym=stellsym,
    mpol=mpol,
    ntor=ntor,
    plasma_dofs=plasma_dofs,
    plasma_mpol=plasma_mpol,
    plasma_ntor=plasma_ntor,
    net_poloidal_current_amperes=net_poloidal_current_amperes,
    net_toroidal_current_amperes=net_toroidal_current_amperes,
    plasma_coil_distance=plasma_coil_distance,
    metric_name=metric_name,
    verbose=verbose,
)
# Out:
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ()
# Constraint types: ()
# Constraint units: ()
# Constraint values: []
# Objective names: f_B
# Objective units: None
# Objective weights: 1.0
# Numerical parameters:
#     c_init: 1.0
#     c_growth_rate: 2.0
#     xstop_outer: 1e-06
#     ctol_outer: 1e-06
#     fstop_inner: 1e-06
#     xstop_inner: 1e-06
#     gtol_inner: 1e-06
#     maxiter_tot: 10000
#     maxiter_inner: 1000
# Plasma-coil distance (m): 0.32575916842151176
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (40,)
# Total # dofs (including auxiliary): 40
# Shape of mu, lam: (Array(0, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 0
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 190
# INNER: starting gradient L2 norm: 4.473644792442285
# INNER: L: 1.0, dx: 0.0, du: 0.0, df: 0.0,
#     grad:0.0, grad/g0:0.0, Average improvement: 0.0
#     Value record: [2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : False
# & (avg_improvement > fstop): False& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): False, False, False
# (dx_norm > xstop): 0.0 > 1e-10)
# (du_norm > xstop): 0.0 > 1e-10
# (df > fstop):      0.0 > 0.0
#
# INNER: L: 1.0, dx: 0.26969578261482846, du: 0.26969578261482846, df: 0.0,
#     grad:1.6514271168759118, grad/g0:0.3691457845883988, Average improvement: 0.1111111111111111
#     Value record: [2. 2. 2. 2. 2. 2. 2. 2. 2. 1.]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, False
# (dx_norm > xstop): 0.3238600820820851 > 1e-10)
# (du_norm > xstop): 0.3238600820820851 > 1e-10
# (df > fstop):      0.0 > 0.0
#
# INNER: L: 0.2755825151567746, dx: 0.06487757525910659, du: 0.2205415710963598, df: 0.7244174848432254,
#     grad:0.9683897029066764, grad/g0:0.21646548794903447, Average improvement: 0.19160194276035838
#     Value record: [2.         2.         2.         2.         2.         2.
#  2.         2.         1.         0.27558252]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.11215401625525308 > 1e-10)
# (du_norm > xstop): 0.3038203900399566 > 1e-10
# (df > fstop):      0.7244174848432254 > 0.0
#
# INNER: L: 0.14181984093295288, dx: 0.12495102410856222, du: 0.06007344884945563, df: 0.13376267422382174,
#     grad:0.36748111307333303, grad/g0:0.08214356081514353, Average improvement: 0.2064644621185608
#     Value record: [2.         2.         2.         2.         2.         2.
#  2.         1.         0.27558252 0.14181984]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.201754060972817 > 1e-10)
# (du_norm > xstop): 0.11366477723441785 > 1e-10
# (df > fstop):      0.13376267422382174 > 0.0
#
# INNER: L: 0.03868168743429053, dx: 0.04047775154195565, du: 0.09739852028474481, df: 0.10313815349866234,
#     grad:0.2946444930795467, grad/g0:0.06586229053708402, Average improvement: 0.2179242569517455
#     Value record: [2.         2.         2.         2.         2.         2.
#  1.         0.27558252 0.14181984 0.03868169]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.08447472977870155 > 1e-10)
# (du_norm > xstop): 0.16041141033917827 > 1e-10
# (df > fstop):      0.10313815349866234 > 0.0
#
# INNER: L: 0.022938209764530537, dx: 0.02588826187417037, du: 0.023449238045152067, df: 0.015743477669759996,
#     grad:0.19720656346165155, grad/g0:0.04408185553640952, Average improvement: 0.2196735322483855
#     Value record: [2.         2.         2.         2.         2.         1.
#  0.27558252 0.14181984 0.03868169 0.02293821]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.06990046000551779 > 1e-10)
# (du_norm > xstop): 0.05546745796746723 > 1e-10
# (df > fstop):      0.015743477669759996 > 0.0
#
# INNER: L: 0.015993612775387883, dx: 0.008876060861561966, du: 0.023848313711169092, df: 0.006944596989142654,
#     grad:0.11056247016281852, grad/g0:0.02471418167790193, Average improvement: 0.22044515413606802
#     Value record: [2.         2.         2.         2.         1.         0.27558252
#  0.14181984 0.03868169 0.02293821 0.01599361]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.024218400959309043 > 1e-10)
# (du_norm > xstop): 0.06360265704842052 > 1e-10
# (df > fstop):      0.006944596989142654 > 0.0
#
# INNER: L: 0.013069792577461985, dx: 0.01304939073784694, du: 0.007438238356694619, df: 0.0029238201979258985,
#     grad:0.06915396518462642, grad/g0:0.015458081361634743, Average improvement: 0.22077002304694868
#     Value record: [2.         2.         2.         1.         0.27558252 0.14181984
#  0.03868169 0.02293821 0.01599361 0.01306979]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0380197918447504 > 1e-10)
# (du_norm > xstop): 0.018299199616659163 > 1e-10
# (df > fstop):      0.0029238201979258985 > 0.0
#
# INNER: L: 0.010869359081599698, dx: 0.011485509912584324, du: 0.010017056678235305, df: 0.002200433495862287,
#     grad:0.04923088905316366, grad/g0:0.011004648633779252, Average improvement: 0.22101451565760002
#     Value record: [2.         2.         1.         0.27558252 0.14181984 0.03868169
#  0.02293821 0.01599361 0.01306979 0.01086936]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.027702672391176717 > 1e-10)
# (du_norm > xstop): 0.021468377566837563 > 1e-10
# (df > fstop):      0.002200433495862287 > 0.0
#
# INNER: L: 0.009924549795076221, dx: 0.01366682269486387, du: 0.007543932176268142, df: 0.0009448092865234764,
#     grad:0.08069996763332841, grad/g0:0.018038975237743917, Average improvement: 0.22111949446721374
#     Value record: [2.         1.         0.27558252 0.14181984 0.03868169 0.02293821
#  0.01599361 0.01306979 0.01086936 0.00992455]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.03206179990307848 > 1e-10)
# (du_norm > xstop): 0.017738645794378893 > 1e-10
# (df > fstop):      0.0009448092865234764 > 0.0
#
# INNER: L: 0.00962710095201499, dx: 0.003100796984330377, du: 0.011440442860844724, df: 0.0002974488430612307,
#     grad:0.02636590716140526, grad/g0:0.005893607647604804, Average improvement: 0.11004143322755389
#     Value record: [1.         0.27558252 0.14181984 0.03868169 0.02293821 0.01599361
#  0.01306979 0.01086936 0.00992455 0.0096271 ]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.007873004105379996 > 1e-10)
# (du_norm > xstop): 0.03215780927247916 > 1e-10
# (df > fstop):      0.0002974488430612307 > 0.0
#
# INNER: L: 0.009303281490212681, dx: 0.0016156973868732688, du: 0.002400333552425855, df: 0.00032381946180230943,
#     grad:0.017971355573811847, grad/g0:0.004017161935648626, Average improvement: 0.029586581518506884
#     Value record: [0.27558252 0.14181984 0.03868169 0.02293821 0.01599361 0.01306979
#  0.01086936 0.00992455 0.0096271  0.00930328]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.004780541769592919 > 1e-10)
# (du_norm > xstop): 0.006323481073138783 > 1e-10
# (df > fstop):      0.00032381946180230943 > 0.0
#
# INNER: L: 0.009223993840426315, dx: 0.004271740966097101, du: 0.003187810175885663, df: 7.928764978636614e-05,
#     grad:0.014249214450653878, grad/g0:0.0031851465889125366, Average improvement: 0.014732871899169622
#     Value record: [0.14181984 0.03868169 0.02293821 0.01599361 0.01306979 0.01086936
#  0.00992455 0.0096271  0.00930328 0.00922399]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.01108850041569227 > 1e-10)
# (du_norm > xstop): 0.0073660316056869315 > 1e-10
# (df > fstop):      7.928764978636614e-05 > 0.0
#
# INNER: L: 0.009130767061369836, dx: 0.0035231897325054685, du: 0.002421546976420496, df: 9.322677905647912e-05,
#     grad:0.020314653846972983, grad/g0:0.004540962635498528, Average improvement: 0.003283435596991189
#     Value record: [0.03868169 0.02293821 0.01599361 0.01306979 0.01086936 0.00992455
#  0.0096271  0.00930328 0.00922399 0.00913077]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.010093953520537527 > 1e-10)
# (du_norm > xstop): 0.006970452059347862 > 1e-10
# (df > fstop):      9.322677905647912e-05 > 0.0
#
# INNER: L: 0.009074308651796885, dx: 0.0030183593638552775, du: 0.0013775363732954219, df: 5.645840957295076e-05,
#     grad:0.010536614188626234, grad/g0:0.0023552639240439132, Average improvement: 0.0015404334569704056
#     Value record: [0.02293821 0.01599361 0.01306979 0.01086936 0.00992455 0.0096271
#  0.00930328 0.00922399 0.00913077 0.00907431]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.009142826554805557 > 1e-10)
# (du_norm > xstop): 0.0035077975965033324 > 1e-10
# (df > fstop):      5.645840957295076e-05 > 0.0
#
# INNER: L: 0.009030139656916493, dx: 0.002089345567084601, du: 0.002110534711815705, df: 4.416899488039229e-05,
#     grad:0.013949427989155877, grad/g0:0.00311813490707216, Average improvement: 0.00077371923538571
#     Value record: [0.01599361 0.01306979 0.01086936 0.00992455 0.0096271  0.00930328
#  0.00922399 0.00913077 0.00907431 0.00903014]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0056709546776553404 > 1e-10)
# (du_norm > xstop): 0.0051159981147158 > 1e-10
# (df > fstop):      4.416899488039229e-05 > 0.0
#
# INNER: L: 0.00901161160822346, dx: 0.0016602378963004039, du: 0.0008953344229262486, df: 1.852804869303254e-05,
#     grad:0.0102897705129562, grad/g0:0.002300086616250713, Average improvement: 0.0004509089965820582
#     Value record: [0.01306979 0.01086936 0.00992455 0.0096271  0.00930328 0.00922399
#  0.00913077 0.00907431 0.00903014 0.00901161]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.004440923793130383 > 1e-10)
# (du_norm > xstop): 0.0027593353421283347 > 1e-10
# (df > fstop):      1.852804869303254e-05 > 0.0
#
# INNER: L: 0.00899389267640434, dx: 0.0017589505749221607, du: 0.0006484398646724927, df: 1.771893181912003e-05,
#     grad:0.009977216820823441, grad/g0:0.0022302210577108883, Average improvement: 0.00020838515613281748
#     Value record: [0.01086936 0.00992455 0.0096271  0.00930328 0.00922399 0.00913077
#  0.00907431 0.00903014 0.00901161 0.00899389]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.004529376979555386 > 1e-10)
# (du_norm > xstop): 0.001708935395463539 > 1e-10
# (df > fstop):      1.771893181912003e-05 > 0.0
#
# INNER: L: 0.008975185187401617, dx: 0.00511017862162523, du: 0.003351228046703074, df: 1.8707489002723482e-05,
#     grad:0.013775550833285992, grad/g0:0.003079267906240169, Average improvement: 0.00010548495640828938
#     Value record: [0.00992455 0.0096271  0.00930328 0.00922399 0.00913077 0.00907431
#  0.00903014 0.00901161 0.00899389 0.00897519]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.013229341160391128 > 1e-10)
# (du_norm > xstop): 0.008954021826372106 > 1e-10
# (df > fstop):      1.8707489002723482e-05 > 0.0
#
# INNER: L: 0.00893914509234468, dx: 0.002310280705062076, du: 0.0027998979165631582, df: 3.604009505693735e-05,
#     grad:0.010812452246273427, grad/g0:0.0024169223860910543, Average improvement: 7.64395399633679e-05
#     Value record: [0.0096271  0.00930328 0.00922399 0.00913077 0.00907431 0.00903014
#  0.00901161 0.00899389 0.00897519 0.00893915]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.006483266894664778 > 1e-10)
# (du_norm > xstop): 0.007269923449407784 > 1e-10
# (df > fstop):      3.604009505693735e-05 > 0.0
#
# INNER: L: 0.008925486133213983, dx: 0.0011233056978216596, du: 0.001415771293407949, df: 1.3658959130696466e-05,
#     grad:0.005775617986276614, grad/g0:0.001291031866462412, Average improvement: 4.197726188874424e-05
#     Value record: [0.00930328 0.00922399 0.00913077 0.00907431 0.00903014 0.00901161
#  0.00899389 0.00897519 0.00893915 0.00892549]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0032982335798535578 > 1e-10)
# (du_norm > xstop): 0.0038206841116699463 > 1e-10
# (df > fstop):      1.3658959130696466e-05 > 0.0
#
# INNER: L: 0.008915707930550194, dx: 0.0010431044609682041, du: 0.0004030594281587927, df: 9.778202663788746e-06,
#     grad:0.004830764297229316, grad/g0:0.0010798274162021858, Average improvement: 3.425398998623564e-05
#     Value record: [0.00922399 0.00913077 0.00907431 0.00903014 0.00901161 0.00899389
#  0.00897519 0.00893915 0.00892549 0.00891571]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0030733482115104524 > 1e-10)
# (du_norm > xstop): 0.0012035540008735158 > 1e-10
# (df > fstop):      9.778202663788746e-06 > 0.0
#
# INNER: L: 0.008908757190857921, dx: 0.001313851852037033, du: 0.0004359931378398945, df: 6.95073969227307e-06,
#     grad:0.005899932607884477, grad/g0:0.0013188200855489786, Average improvement: 2.4667763390212747e-05
#     Value record: [0.00913077 0.00907431 0.00903014 0.00901161 0.00899389 0.00897519
#  0.00893915 0.00892549 0.00891571 0.00890876]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0033409828123425263 > 1e-10)
# (du_norm > xstop): 0.0013850055763246782 > 1e-10
# (df > fstop):      6.95073969227307e-06 > 0.0
#
# INNER: L: 0.008902171190569965, dx: 0.0027468176687216812, du: 0.0014877853988390318, df: 6.586000287956556e-06,
#     grad:0.0059686664935912235, grad/g0:0.0013341842659646576, Average improvement: 1.9126384580768947e-05
#     Value record: [0.00907431 0.00903014 0.00901161 0.00899389 0.00897519 0.00893915
#  0.00892549 0.00891571 0.00890876 0.00890217]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.006820407909163687 > 1e-10)
# (du_norm > xstop): 0.003656799150952577 > 1e-10
# (df > fstop):      6.586000287956556e-06 > 0.0
#
# INNER: L: 0.008893795473605233, dx: 0.0016308673746819099, du: 0.0011919622159835006, df: 8.375716964732077e-06,
#     grad:0.004398911610025883, grad/g0:0.0009832947885038492, Average improvement: 1.5149353701251146e-05
#     Value record: [0.00903014 0.00901161 0.00899389 0.00897519 0.00893915 0.00892549
#  0.00891571 0.00890876 0.00890217 0.0088938 ]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.003898089679522737 > 1e-10)
# (du_norm > xstop): 0.003751803164354133 > 1e-10
# (df > fstop):      8.375716964732077e-06 > 0.0
#
# INNER: L: 0.008887821328128768, dx: 0.0009464547625948616, du: 0.0007512655998875596, df: 5.974145476464812e-06,
#     grad:0.0034914710541380897, grad/g0:0.0007804533475783624, Average improvement: 1.3754475566076954e-05
#     Value record: [0.00901161 0.00899389 0.00897519 0.00893915 0.00892549 0.00891571
#  0.00890876 0.00890217 0.0088938  0.00888782]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0024382691313974314 > 1e-10)
# (du_norm > xstop): 0.002037268485172963 > 1e-10
# (df > fstop):      5.974145476464812e-06 > 0.0
#
# INNER: L: 0.008883866564586253, dx: 0.0014431175682254743, du: 0.0005107981619946938, df: 3.9547635425143945e-06,
#     grad:0.004416862430952241, grad/g0:0.0009873073603013875, Average improvement: 1.2225123535342994e-05
#     Value record: [0.00899389 0.00897519 0.00893915 0.00892549 0.00891571 0.00890876
#  0.00890217 0.0088938  0.00888782 0.00888387]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0033885905826730287 > 1e-10)
# (du_norm > xstop): 0.0013091023760723795 > 1e-10
# (df > fstop):      3.9547635425143945e-06 > 0.0
#
# INNER: L: 0.008881254315307773, dx: 0.0006469796623949434, du: 0.0009697839977911396, df: 2.6122492784805967e-06,
#     grad:0.0026966412314470786, grad/g0:0.0006027839393960709, Average improvement: 1.0436763565982674e-05
#     Value record: [0.00897519 0.00893915 0.00892549 0.00891571 0.00890876 0.00890217
#  0.0088938  0.00888782 0.00888387 0.00888125]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0014261141883976551 > 1e-10)
# (du_norm > xstop): 0.0024237056482530623 > 1e-10
# (df > fstop):      2.6122492784805967e-06 > 0.0
#
# INNER: L: 0.00887950356083391, dx: 0.0002519138391654293, du: 0.0004054446086847899, df: 1.7507544738636083e-06,
#     grad:0.001721963238935503, grad/g0:0.0003849128213854985, Average improvement: 6.626836834530036e-06
#     Value record: [0.00893915 0.00892549 0.00891571 0.00890876 0.00890217 0.0088938
#  0.00888782 0.00888387 0.00888125 0.0088795 ]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0006621697131410219 > 1e-10)
# (du_norm > xstop): 0.0009747393541184441 > 1e-10
# (df > fstop):      1.7507544738636083e-06 > 0.0
#
# INNER: L: 0.008878704857513211, dx: 0.0005197879222697752, du: 0.00026787408310434695, df: 7.987033206983268e-07,
#     grad:0.0014689755483689973, grad/g0:0.0003283621334556254, Average improvement: 5.19791952230802e-06
#     Value record: [0.00892549 0.00891571 0.00890876 0.00890217 0.0088938  0.00888782
#  0.00888387 0.00888125 0.0088795  0.0088787 ]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.001166669510137573 > 1e-10)
# (du_norm > xstop): 0.0006002675918669251 > 1e-10
# (df > fstop):      7.987033206983268e-07 > 0.0
#
# INNER: L: 0.008877978081881135, dx: 0.0005401413798319541, du: 0.00015720560493823912, df: 7.267756320754326e-07,
#     grad:0.0021019064949906715, grad/g0:0.00046984206223560794, Average improvement: 4.192205407673208e-06
#     Value record: [0.00891571 0.00890876 0.00890217 0.0088938  0.00888782 0.00888387
#  0.00888125 0.0088795  0.0088787  0.00887798]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.00109316319738445 > 1e-10)
# (du_norm > xstop): 0.0004325769954522223 > 1e-10
# (df > fstop):      7.267756320754326e-07 > 0.0
#
# INNER: L: 0.008877526483234774, dx: 0.0005352564570639227, du: 0.0001031498591668136, df: 4.515986463619198e-07,
#     grad:0.0017725503171581083, grad/g0:0.0003962206208576574, Average improvement: 3.4700786247941912e-06
#     Value record: [0.00890876 0.00890217 0.0088938  0.00888782 0.00888387 0.00888125
#  0.0088795  0.0088787  0.00887798 0.00887753]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0011224728569943477 > 1e-10)
# (du_norm > xstop): 0.0003442278176752277 > 1e-10
# (df > fstop):      4.515986463619198e-07 > 0.0
#
# INNER: L: 0.008877060549129963, dx: 0.00036422665792731554, du: 0.0002541624828300927, df: 4.6593410481070296e-07,
#     grad:0.0010765130526745655, grad/g0:0.00024063444967584643, Average improvement: 2.790071271111319e-06
#     Value record: [0.00890217 0.0088938  0.00888782 0.00888387 0.00888125 0.0088795
#  0.0088787  0.00887798 0.00887753 0.00887706]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0007451704735839772 > 1e-10)
# (du_norm > xstop): 0.0006215899623914338 > 1e-10
# (df > fstop):      4.6593410481070296e-07 > 0.0
#
# INNER: L: 0.008876693227027638, dx: 0.00026667468879345603, du: 0.00013818487291384067, df: 3.673221023250961e-07,
#     grad:0.0010496472913060443, grad/g0:0.00023462910892686523, Average improvement: 1.9002496197327654e-06
#     Value record: [0.0088938  0.00888782 0.00888387 0.00888125 0.0088795  0.0088787
#  0.00887798 0.00887753 0.00887706 0.00887669]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0006155325992617723 > 1e-10)
# (du_norm > xstop): 0.0003611542610838498 > 1e-10
# (df > fstop):      3.673221023250961e-07 > 0.0
#
# INNER: L: 0.00887644317578221, dx: 0.00031568675004090604, du: 8.525887989743863e-05, df: 2.5005124542828994e-07,
#     grad:0.0009591549528936101, grad/g0:0.00021440123152244753, Average improvement: 1.2642391496175964e-06
#     Value record: [0.00888782 0.00888387 0.00888125 0.0088795  0.0088787  0.00887798
#  0.00887753 0.00887706 0.00887669 0.00887644]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0006853998174793784 > 1e-10)
# (du_norm > xstop): 0.0002670315486508073 > 1e-10
# (df > fstop):      2.5005124542828994e-07 > 0.0
#
# INNER: L: 0.008876220604228723, dx: 0.0003119045977664041, du: 0.00012338962981028087, df: 2.2257155348620605e-07,
#     grad:0.0010499184136055861, grad/g0:0.0002346897132689891, Average improvement: 8.495511508366866e-07
#     Value record: [0.00888387 0.00888125 0.0088795  0.0088787  0.00887798 0.00887753
#  0.00887706 0.00887669 0.00887644 0.00887622]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0006759590311836721 > 1e-10)
# (du_norm > xstop): 0.0003239620876817611 > 1e-10
# (df > fstop):      2.2257155348620605e-07 > 0.0
#
# INNER: L: 0.008876053599960434, dx: 0.00022516743011858405, du: 0.00016765632472122636, df: 1.6700426828941684e-07,
#     grad:0.0010067711830128985, grad/g0:0.00022504495321437322, Average improvement: 5.778572608154443e-07
#     Value record: [0.00888125 0.0088795  0.0088787  0.00887798 0.00887753 0.00887706
#  0.00887669 0.00887644 0.00887622 0.00887605]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0004908359959256014 > 1e-10)
# (du_norm > xstop): 0.0003947923723437855 > 1e-10
# (df > fstop):      1.6700426828941684e-07 > 0.0
#
# INNER: L: 0.008875988960180471, dx: 5.149510812060831e-05, du: 0.00027304366857128123, df: 6.463977996265524e-08,
#     grad:0.00042664015096279364, grad/g0:9.536746227227376e-05, Average improvement: 3.9051118371533846e-07
#     Value record: [0.0088795  0.0088787  0.00887798 0.00887753 0.00887706 0.00887669
#  0.00887644 0.00887622 0.00887605 0.00887599]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.00014312161037012728 > 1e-10)
# (du_norm > xstop): 0.0005899410271928215 > 1e-10
# (df > fstop):      6.463977996265524e-08 > 0.0
#
# INNER: L: 0.008875939119094397, dx: 3.3317049282605496e-05, du: 6.555825308267562e-05, df: 4.9841086074281504e-08,
#     grad:0.0003042307935313959, grad/g0:6.800512951885659e-05, Average improvement: 3.073042687571112e-07
#     Value record: [0.0088787  0.00887798 0.00887753 0.00887706 0.00887669 0.00887644
#  0.00887622 0.00887605 0.00887599 0.00887594]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 9.502803363705034e-05 > 1e-10)
# (du_norm > xstop): 0.00013763222927464392 > 1e-10
# (df > fstop):      4.9841086074281504e-08 > 0.0
#
# INNER: L: 0.008875915209638688, dx: 7.860823294937938e-05, du: 5.7312836095157406e-05, df: 2.3909455708695515e-08,
#     grad:0.0002942123088047958, grad/g0:6.576568378916315e-05, Average improvement: 2.2920802693858489e-07
#     Value record: [0.00887798 0.00887753 0.00887706 0.00887669 0.00887644 0.00887622
#  0.00887605 0.00887599 0.00887594 0.00887592]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0001949887840392263 > 1e-10)
# (du_norm > xstop): 0.00012420994418846988 > 1e-10
# (df > fstop):      2.3909455708695515e-08 > 0.0
#
# INNER: L: 0.008875887317558272, dx: 0.00011020777746712992, du: 3.771719453200912e-05, df: 2.7892080416147547e-08,
#     grad:0.00025140635956551216, grad/g0:5.619721082689324e-05, Average improvement: 1.8212951961127684e-07
#     Value record: [0.00887753 0.00887706 0.00887669 0.00887644 0.00887622 0.00887605
#  0.00887599 0.00887594 0.00887592 0.00887589]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0002394558045616322 > 1e-10)
# (du_norm > xstop): 8.957879198413785e-05 > 1e-10
# (df > fstop):      2.7892080416147547e-08 > 0.0
#
# INNER: L: 0.008875860975909212, dx: 0.0001815648513160198, du: 9.55107269901857e-05, df: 2.6341649059929972e-08,
#     grad:0.0006701523403096162, grad/g0:0.00014980007832578985, Average improvement: 1.332859134167465e-07
#     Value record: [0.00887706 0.00887669 0.00887644 0.00887622 0.00887605 0.00887599
#  0.00887594 0.00887592 0.00887589 0.00887586]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0003724237624796175 > 1e-10)
# (du_norm > xstop): 0.00019837766488796398 > 1e-10
# (df > fstop):      2.6341649059929972e-08 > 0.0
#
# INNER: L: 0.00887585431025488, dx: 4.2939836239222484e-05, du: 0.0001443350570483145, df: 6.665654332313475e-09,
#     grad:0.00016822126952111598, grad/g0:3.760273274384831e-05, Average improvement: 9.321297475088178e-08
#     Value record: [0.00887669 0.00887644 0.00887622 0.00887605 0.00887599 0.00887594
#  0.00887592 0.00887589 0.00887586 0.00887585]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.0001078314858979799 > 1e-10)
# (du_norm > xstop): 0.00033050128667020263 > 1e-10
# (df > fstop):      6.665654332313475e-09 > 0.0
#
# INNER: L: 0.008875832011650783, dx: 1.3944063210091784e-05, du: 4.963932215683445e-05, df: 2.2298604096873675e-08,
#     grad:0.00010669814626835951, grad/g0:2.3850384019896686e-05, Average improvement: 6.790712571405775e-08
#     Value record: [0.00887644 0.00887622 0.00887605 0.00887599 0.00887594 0.00887592
#  0.00887589 0.00887586 0.00887585 0.00887583]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 4.2612002890687016e-05 > 1e-10)
# (du_norm > xstop): 0.0001198874776341272 > 1e-10
# (df > fstop):      2.2298604096873675e-08 > 0.0
#
# INNER: L: 0.008875828568285199, dx: 2.419750529423126e-05, du: 2.042718501681682e-05, df: 3.4433655839855026e-09,
#     grad:0.00010391867149611585, grad/g0:2.3229084184706536e-05, Average improvement: 4.3559549280477695e-08
#     Value record: [0.00887622 0.00887605 0.00887599 0.00887594 0.00887592 0.00887589
#  0.00887586 0.00887585 0.00887583 0.00887583]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 6.957981896009294e-05 > 1e-10)
# (du_norm > xstop): 4.6256401058716455e-05 > 1e-10
# (df > fstop):      3.4433655839855026e-09 > 0.0
#
# INNER: L: 0.008875825668690347, dx: 5.609633347639087e-05, du: 3.9602182485147075e-05, df: 2.899594852417975e-09,
#     grad:0.0001817069498306408, grad/g0:4.061720549150752e-05, Average improvement: 2.532569667636671e-08
#     Value record: [0.00887605 0.00887599 0.00887594 0.00887592 0.00887589 0.00887586
#  0.00887585 0.00887583 0.00887583 0.00887583]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 0.00010892780043788798 > 1e-10)
# (du_norm > xstop): 7.96158414026744e-05 > 1e-10
# (df > fstop):      2.899594852417975e-09 > 0.0
#
# INNER: L: 0.008875823443475673, dx: 1.571046696725517e-05, du: 4.038586650913354e-05, df: 2.2252146739815126e-09,
#     grad:8.124617363013753e-05, grad/g0:1.816106941869719e-05, Average improvement: 1.8390744977625185e-08
#     Value record: [0.00887599 0.00887594 0.00887592 0.00887589 0.00887586 0.00887585
#  0.00887583 0.00887583 0.00887583 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 3.3215548935986056e-05 > 1e-10)
# (du_norm > xstop): 8.456250462806662e-05 > 1e-10
# (df > fstop):      2.2252146739815126e-09 > 0.0
#
# INNER: L: 0.008875821458139976, dx: 2.1240421927779668e-05, du: 5.944776425107688e-06, df: 1.9853356961890833e-09,
#     grad:5.7734814108938954e-05, grad/g0:1.2905542748158138e-05, Average improvement: 1.307343938005936e-08
#     Value record: [0.00887594 0.00887592 0.00887589 0.00887586 0.00887585 0.00887583
#  0.00887583 0.00887583 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 4.319918553578632e-05 > 1e-10)
# (du_norm > xstop): 1.6320585376907063e-05 > 1e-10
# (df > fstop):      1.9853356961890833e-09 > 0.0
#
# INNER: L: 0.008875820226917339, dx: 1.2293182743115805e-05, du: 1.0889626233707902e-05, df: 1.2312226377320101e-09,
#     grad:5.5895432511472965e-05, grad/g0:1.2494383238897722e-05, Average improvement: 1.0553635705507861e-08
#     Value record: [0.00887592 0.00887589 0.00887586 0.00887585 0.00887583 0.00887583
#  0.00887583 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 2.4958307513098106e-05 > 1e-10)
# (du_norm > xstop): 2.3091551647047584e-05 > 1e-10
# (df > fstop):      1.2312226377320101e-09 > 0.0
#
# INNER: L: 0.008875819619316279, dx: 1.5209620451237665e-05, du: 4.236722275108299e-06, df: 6.076010597433346e-10,
#     grad:8.336802764785068e-05, grad/g0:1.863537037824091e-05, Average improvement: 7.522026888129616e-09
#     Value record: [0.00887589 0.00887586 0.00887585 0.00887583 0.00887583 0.00887583
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 3.072920609679842e-05 > 1e-10)
# (du_norm > xstop): 1.2516373395176009e-05 > 1e-10
# (df > fstop):      6.076010597433346e-10 > 0.0
#
# INNER: L: 0.008875819172984387, dx: 1.3834765606256239e-05, du: 6.63934523108282e-06, df: 4.46331891584828e-10,
#     grad:2.9082275336229253e-05, grad/g0:6.500801177903184e-06, Average improvement: 4.644769424980155e-09
#     Value record: [0.00887586 0.00887585 0.00887583 0.00887583 0.00887583 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 2.962905161006693e-05 > 1e-10)
# (du_norm > xstop): 1.244035485764613e-05 > 1e-10
# (df > fstop):      4.46331891584828e-10 > 0.0
#
# INNER: L: 0.008875818675273225, dx: 2.5705682052592355e-06, du: 1.3403155164447778e-05, df: 4.977111622145314e-10,
#     grad:2.1355016364244156e-05, grad/g0:4.773516306060112e-06, Average improvement: 3.959442406080273e-09
#     Value record: [0.00887585 0.00887583 0.00887583 0.00887583 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 6.7440537643121985e-06 > 1e-10)
# (du_norm > xstop): 2.758279305014415e-05 > 1e-10
# (df > fstop):      4.977111622145314e-10 > 0.0
#
# INNER: L: 0.00887581856584213, dx: 4.6051584239540505e-06, du: 2.0488429585240753e-06, df: 1.0943109439442988e-10,
#     grad:1.9537549697042492e-05, grad/g0:4.367255471433262e-06, Average improvement: 1.493978739138134e-09
#     Value record: [0.00887583 0.00887583 0.00887583 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.1095167893143488e-05 > 1e-10)
# (du_norm > xstop): 6.3998433846130206e-06 > 1e-10
# (df > fstop):      1.0943109439442988e-10 > 0.0
#
# INNER: L: 0.008875818449621795, dx: 4.901375715484629e-06, du: 2.8395773282921957e-06, df: 1.1622033543878807e-10,
#     grad:1.9784323258318516e-05, grad/g0:4.422417106459118e-06, Average improvement: 1.1242959337440548e-09
#     Value record: [0.00887583 0.00887583 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.3254915477757408e-05 > 1e-10)
# (du_norm > xstop): 7.718612995057608e-06 > 1e-10
# (df > fstop):      1.1622033543878807e-10 > 0.0
#
# INNER: L: 0.008875818343702796, dx: 8.098137114050802e-06, du: 3.7453304822908446e-06, df: 1.0591899926581938e-10,
#     grad:2.4626098211647146e-05, grad/g0:5.504705749828449e-06, Average improvement: 8.138875056160374e-10
#     Value record: [0.00887583 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 2.0741167399557947e-05 > 1e-10)
# (du_norm > xstop): 8.972857118027376e-06 > 1e-10
# (df > fstop):      1.0591899926581938e-10 > 0.0
#
# INNER: L: 0.00887581825155502, dx: 4.062310850826839e-06, du: 4.717245003080611e-06, df: 9.214777552113418e-11,
#     grad:1.7667617546411928e-05, grad/g0:3.949266954823807e-06, Average improvement: 5.768800724537732e-10
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.211394653150218e-05 > 1e-10)
# (du_norm > xstop): 1.2028890609885549e-05 > 1e-10
# (df > fstop):      9.214777552113418e-11 > 0.0
#
# INNER: L: 0.008875818184809868, dx: 2.7355706992936157e-06, du: 3.290997082671016e-06, df: 6.674515280746807e-11,
#     grad:1.2971019352049641e-05, grad/g0:2.8994298729221204e-06, Average improvement: 3.637033454113715e-10
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 4.95437158158232e-06 > 1e-10)
# (du_norm > xstop): 8.901495209905533e-06 > 1e-10
# (df > fstop):      6.674515280746807e-11 > 0.0
#
# INNER: L: 0.008875818145931011, dx: 7.189665562828268e-06, du: 4.454094863534144e-06, df: 3.887885673126146e-11,
#     grad:2.0340034369159477e-05, grad/g0:4.546635978681556e-06, Average improvement: 2.3122070307795498e-10
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.3356354912603107e-05 > 1e-10)
# (du_norm > xstop): 9.2537628417015e-06 > 1e-10
# (df > fstop):      3.887885673126146e-11 > 0.0
#
# INNER: L: 0.008875818098805428, dx: 5.410928288662048e-06, du: 2.7462402449189053e-06, df: 4.7125582949836264e-11,
#     grad:2.9269641442014312e-05, grad/g0:6.5426833823423005e-06, Average improvement: 1.6894565010089963e-10
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.2505642685273174e-05 > 1e-10)
# (du_norm > xstop): 6.331779995513793e-06 > 1e-10
# (df > fstop):      4.7125582949836264e-11 > 0.0
#
# INNER: L: 0.008875818084983817, dx: 1.7751737481624258e-06, du: 7.0687944961866805e-06, df: 1.3821610522768424e-11,
#     grad:1.053387823685053e-05, grad/g0:2.3546523529642585e-06, Average improvement: 1.2088895220511522e-10
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 3.7491734734911307e-06 > 1e-10)
# (du_norm > xstop): 1.58543746937159e-05 > 1e-10
# (df > fstop):      1.3821610522768424e-11 > 0.0
#
# INNER: L: 0.00887581805620033, dx: 6.952437583626625e-07, du: 2.177092554360188e-06, df: 2.8783487746042447e-11,
#     grad:6.381688157292945e-06, grad/g0:1.4265075689679437e-06, Average improvement: 6.878587726417201e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 2.369935324966823e-06 > 1e-10)
# (du_norm > xstop): 4.6972056722862835e-06 > 1e-10
# (df > fstop):      2.8783487746042447e-11 > 0.0
#
# INNER: L: 0.008875818043461806, dx: 2.253342180170287e-06, du: 1.6224866320389558e-06, df: 1.2738523777477972e-11,
#     grad:8.15057653801518e-06, grad/g0:1.8219096321157757e-06, Average improvement: 5.8042258306732916e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 5.608919248259785e-06 > 1e-10)
# (du_norm > xstop): 3.5400340676226565e-06 > 1e-10
# (df > fstop):      1.2738523777477972e-11 > 0.0
#
# INNER: L: 0.008875818028114822, dx: 2.5248574854648542e-06, du: 5.709467163191628e-07, df: 1.5346984100217398e-11,
#     grad:8.284670783967316e-06, grad/g0:1.8518839041408307e-06, Average improvement: 4.683410815800284e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 6.347498978199148e-06 > 1e-10)
# (du_norm > xstop): 1.9575139411526577e-06 > 1e-10
# (df > fstop):      1.5346984100217398e-11 > 0.0
#
# INNER: L: 0.008875818012113875, dx: 2.1916431415924115e-06, du: 7.072570625751244e-07, df: 1.600094709508504e-11,
#     grad:1.4198157942573349e-05, grad/g0:3.173733857135802e-06, Average improvement: 3.6843213472365695e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 5.961831250743286e-06 > 1e-10)
# (du_norm > xstop): 1.8544963397189778e-06 > 1e-10
# (df > fstop):      1.600094709508504e-11 > 0.0
#
# INNER: L: 0.008875818002839805, dx: 3.094777529171616e-06, du: 9.356782040348206e-07, df: 9.27406935968822e-12,
#     grad:5.978021364489921e-06, grad/g0:1.3362753731787353e-06, Average improvement: 2.7635023898871698e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 8.217729591685054e-06 > 1e-10)
# (du_norm > xstop): 2.8935514716794716e-06 > 1e-10
# (df > fstop):      9.27406935968822e-12 > 0.0
#
# INNER: L: 0.00887581798648384, dx: 1.0876663750700177e-06, du: 2.3110672850972593e-06, df: 1.6355965193337596e-11,
#     grad:4.176249013939267e-06, grad/g0:9.335227108317954e-07, Average improvement: 2.2036225275079424e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 3.330877912788476e-06 > 1e-10)
# (du_norm > xstop): 5.591410706038736e-06 > 1e-10
# (df > fstop):      1.6355965193337596e-11 > 0.0
#
# INNER: L: 0.008875817979732538, dx: 1.722950315821703e-06, du: 7.001770424440205e-07, df: 6.7513026419385724e-12,
#     grad:6.6801371670658835e-06, grad/g0:1.4932202883767652e-06, Average improvement: 1.8466497042932437e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 4.5779040683114165e-06 > 1e-10)
# (du_norm > xstop): 1.8736407964538599e-06 > 1e-10
# (df > fstop):      6.7513026419385724e-12 > 0.0
#
# INNER: L: 0.008875817974755836, dx: 6.499569340373546e-07, du: 1.0729933817776003e-06, df: 4.9767013426960105e-12,
#     grad:3.4081306522672336e-06, grad/g0:7.618241524282132e-07, Average improvement: 1.3783287975472408e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 1.7045485723899237e-06 > 1e-10)
# (du_norm > xstop): 3.525553715597379e-06 > 1e-10
# (df > fstop):      4.9767013426960105e-12 > 0.0
#
# INNER: L: 0.008875817971531105, dx: 2.5275201484455806e-07, du: 4.9517315339342e-07, df: 3.224731245921042e-12,
#     grad:2.5353353957972e-06, grad/g0:5.667270231379034e-07, Average improvement: 1.2605856944711587e-11
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 6.969116537537e-07 > 1e-10)
# (du_norm > xstop): 1.4495463309561303e-06 > 1e-10
# (df > fstop):      3.224731245921042e-12 > 0.0
#
# INNER: L: 0.00887581797011686, dx: 7.690106825636311e-07, du: 6.150271896897497e-07, df: 1.4142454568544238e-12,
#     grad:2.479711129891804e-06, grad/g0:5.542932541450305e-07, Average improvement: 9.564830023690697e-12
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# ...
# (dx_norm > xstop): 2.148318320870637e-06 > 1e-10)
# (du_norm > xstop): 1.6405003919894406e-06 > 1e-10
# (df > fstop):      1.4142454568544238e-12 > 0.0
#
# INNER: L: 0.008875817967981545, dx: 8.239777696539274e-07, du: 3.8487603964397694e-07, df: 2.1353144946667513e-12,
#     grad:3.980407708461235e-06, grad/g0:8.897460332983258e-07, Average improvement: 8.386695658933895e-12
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 2.246079800557402e-06 > 1e-10)
# (du_norm > xstop): 8.085555366728197e-07 > 1e-10
# (df > fstop):      2.1353144946667513e-12 > 0.0
#
# INNER: L: 0.008875817967330902, dx: 2.438919051925281e-07, du: 6.015823439806353e-07, df: 6.50642734134621e-13,
#     grad:1.6575608770355482e-06, grad/g0:3.705168724695821e-07, Average improvement: 6.7537688404802525e-12
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : True
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 6.860395900938756e-07 > 1e-10)
# (du_norm > xstop): 1.8444639094956156e-06 > 1e-10
# (df > fstop):      6.50642734134621e-13 > 0.0
#
# INNER: L: 0.008875817966365773, dx: 1.9291032731308388e-07, du: 1.4301155499019224e-07, df: 9.651290183709804e-13,
#     grad:9.902332383128535e-07, grad/g0:2.2134820359134012e-07, Average improvement: 5.083122387512024e-12
#     Value record: [0.00887582 0.00887582 0.00887582 0.00887582 0.00887582 0.00887582
#  0.00887582 0.00887582 0.00887582 0.00887582]
#     Stopping criteria:
# (iter_num < maxiter): True
# & (err > gtol) : False
# & (avg_improvement > fstop): True& ((dx_norm > xstop) | (du_norm > xstop) | (df > fstop)): True, True, True
# (dx_norm > xstop): 5.415346339455965e-07 > 1e-10)
# (du_norm > xstop): 4.072314014543258e-07 > 1e-10
# (df > fstop):      9.651290183709804e-13 > 0.0
#
# ----- Solver status summary -----
# Final value of objective f: 0.008875817966365773
# Final Max current potential (dipole density): 374771.4823671854 (A)
# Final Avg current potential (dipole density): 55256.84531013589 (A)
# * Total L-BFGS iteration number: 72
#     Phi scaling constant:  942032.288671926(A)
#     Inner convergence rate in x (scaled): 5.415346339455965e-07, 4.072314014543258e-07
#     Inner convergence rate in f: 9.651290183709804e-13
#
# GG 136649690601379.17
# Unconstrained Hessian condition number: 245.88424967188288
# GG 0.011254207760609739
# * Metric evaluated.
#     f_K = 136649690601379.17
#     VIHP        min max: -885290022900385.8, 922071775528786.2
#     df/dy       min max: -1046417435309464.9, 1883144638552920.5
#     df/dx       min max: -176243672717863.9, 255218717827595.0
#     df/dx dx/dy min max: -9901878876922516.0, 7814327449437429.0
#     dLk/dy min max: -0.8384681643261629, 0.9366807919066327
#     Gradient min, max: {'df_dnet_poloidal_current_amperes': (Array(22996169.14220196, dtype=float64), Array(22996169.14220196, dtype=float64)), 'df_dnet_toroidal_current_amperes': (Array(3474556.32970045, dtype=float64), Array(3474556.32970045, dtype=float64)), 'df_dplasma_coil_distance': (Array(1.94775991e+15, dtype=float64), Array(1.94775991e+15, dtype=float64)), 'df_dplasma_dofs': (Array(-7.85155347e+15, dtype=float64), Array(1.00927267e+16, dtype=float64))}
# * Metric evaluated.
#     f_B = 0.011254207760609739
#     VIHP        min max: -3.4849013026221564e-06, 3.946493396832625e-06
#     df/dy       min max: -1.073821525998271, 1.177657669726322
#     df/dx       min max: -2.878218919196306e-07, 4.233574142593196e-07
#     df/dx dx/dy min max: -2.4398346525959273e-05, 2.8035905900701945e-05
#     dLk/dy min max: -0.8384681643261629, 0.9366807919066327
#     Gradient min, max: {'df_dnet_poloidal_current_amperes': (Array(1.89391793e-09, dtype=float64), Array(1.89391793e-09, dtype=float64)), 'df_dnet_toroidal_current_amperes': (Array(5.91199423e-10, dtype=float64), Array(5.91199423e-10, dtype=float64)), 'df_dplasma_coil_distance': (Array(0.09358412, dtype=float64), Array(0.09358412, dtype=float64)), 'df_dplasma_dofs': (Array(-1.07382052, dtype=float64), Array(1.1776559, dtype=float64))}
# ({'f_B': {'grad': {'df_dnet_poloidal_current_amperes': Array(1.89391793e-09, dtype=float64),
#     'df_dnet_toroidal_current_amperes': Array(5.91199423e-10, dtype=float64),
#     'df_dplasma_coil_distance': Array(0.09358412, dtype=float64),
#     'df_dplasma_dofs': Array([-4.15288539e-02, -3.38259607e-02,  2.20993870e-02,  1.69823722e-01,
#            -4.75490358e-02, -4.22808953e-01,  3.00929939e-01,  1.11972650e-02,
#            -1.22941573e-01, -1.09252880e-01,  2.50638376e-02,  4.04543209e-02,
#             5.56406963e-02,  4.62666214e-03,  9.67091294e-03, -2.28303831e-01,
#             1.53544612e-01, -7.92357435e-02,  4.52803046e-02, -1.35390200e-01,
#            -9.38276191e-03,  3.19123233e-02, -3.58272428e-02,  8.67726560e-02,
#             7.58820246e-02, -2.80891641e-01,  2.94465330e-01,  9.85556215e-02,
#             6.44478769e-02, -1.37825906e-01,  1.81305471e-01,  9.53925162e-02,
#            -1.32312656e-01, -7.48460227e-02, -1.11682063e-01, -4.95960417e-01,
#             2.42749610e-01, -4.60415295e-02, -6.01380510e-01,  1.00906784e-01,
#             1.32025550e-01, -2.99339641e-01,  5.29529127e-02,  2.72919212e-01,
#            -9.27364248e-03, -2.52111577e-03,  1.02411717e+00,  3.89053375e-01,
#            -2.36275123e-01, -5.45520473e-01,  3.35382688e-02, -4.41950788e-02,
#             1.52074550e-01, -5.00747696e-02, -3.40062156e-01, -6.22385896e-02,
#             4.80909537e-02, -6.58896961e-01, -1.02912906e+00,  1.05268440e-01,
#             8.81637295e-01, -1.73165197e-03,  8.69174035e-02, -1.63150682e-01,
#             1.89569405e-03,  2.52742627e-01,  1.15066227e-01, -1.59210056e-01,
#             6.32552415e-01,  1.17765590e+00,  9.70470466e-01, -9.89293508e-01,
#             7.66195566e-03,  3.22481864e-02, -5.06567807e-02, -5.84352494e-02,
#            -7.37287314e-02,  3.68659290e-02,  7.79436844e-02,  1.67037896e-02,
#            -5.75840463e-01, -1.07382052e+00,  3.91568503e-01,  7.87451403e-03,
#            -3.26231321e-02,  1.04801405e-02, -4.99702168e-02, -1.30778726e-01,
#            -6.89788417e-02, -4.34736802e-02, -6.23810861e-02,  1.95779961e-01,
#             8.64793266e-01,  6.85421167e-01,  1.79701108e-02,  1.44389710e-02,
#             1.20468702e-01, -2.00326964e-01,  1.78272592e-01,  2.91455674e-02,
#            -4.55405268e-02,  5.76811306e-02,  4.31917394e-02, -8.15540507e-03,
#             1.88462619e-02, -8.83156892e-02, -1.93977110e-03, -1.79042604e-01,
#            -5.51976824e-02,  5.86290910e-03,  3.50652483e-03, -6.85011134e-02,
#            -5.29035512e-03,  7.28807389e-02,  1.36247730e-01,  5.47290067e-02,
#             3.03441748e-01,  1.44020859e-01, -4.14416476e-03,  3.79655373e-01,
#            -2.65014518e-01, -1.02364114e-01,  4.00452167e-02, -1.86715604e-01,
#            -1.79455980e-01, -8.44911885e-02,  4.72242088e-02, -3.61648000e-01,
#            -4.24247045e-01,  2.62686871e-01, -6.03795200e-02,  4.38330707e-01,
#             1.25387981e-01, -1.24203516e-01,  1.36668315e-01,  1.10978654e-01,
#            -1.47191755e-01, -1.00798154e-01,  2.86170791e-01,  2.96592757e-01,
#            -1.84148833e-01, -5.66190205e-01,  4.37923604e-01, -1.29490963e-03,
#             6.75645826e-04,  2.05625596e-01, -6.62191903e-02,  5.55925756e-02,
#            -4.35123994e-02,  1.93606789e-03, -4.93815901e-01, -2.45844727e-01,
#             4.33294651e-01, -8.25625441e-01,  1.48510568e-02,  6.81279750e-02,
#            -1.78365090e-01,  2.13082066e-01,  1.94242931e-01, -8.91702293e-02,
#            -1.52541912e-01,  3.08651965e-01,  2.29158055e-01, -2.89577144e-01,
#            -5.77549919e-01,  1.87576258e-02,  3.16058585e-02, -1.00495636e-01,
#            -9.11113977e-02, -5.67336663e-02,  2.92369348e-01,  1.40450286e-02,
#             1.89594494e-01, -1.08489799e-01,  3.68930537e-01,  5.37632590e-01,
#            -4.28933450e-03, -3.75871908e-02,  8.25909693e-02, -9.90396100e-02,
#            -1.37461580e-01, -1.39828677e-01,  3.06382517e-02, -7.75413492e-02,
#            -8.33404197e-02, -8.36816448e-02, -5.93157840e-02], dtype=float64)},
#    'value': Array(0.01125421, dtype=float64),
#    'vihp': Array([ 4.55721469e-08,  1.36944714e-07, -8.87111588e-08, -3.93056274e-07,
#           -2.26355985e-06, -2.31529576e-07,  1.09766038e-07, -1.56252798e-08,
#            2.38282283e-07,  6.48894160e-08, -7.27548481e-08, -1.79895523e-08,
#           -2.81563774e-07,  3.94649340e-06, -3.40705947e-07, -2.51877872e-07,
#            7.23673330e-08, -1.15921883e-07,  3.17761465e-08,  6.14125711e-10,
#           -3.31654377e-07,  1.79047055e-07, -3.48490130e-06,  1.15772374e-06,
#            3.33722561e-07,  2.12344582e-07,  5.36597184e-08,  7.33408155e-08,
#            9.37028218e-08,  3.82003353e-07, -5.45175795e-07,  1.25263849e-06,
#           -9.18348764e-07, -5.66140799e-08, -3.38093197e-07,  6.25496107e-08,
#           -8.38567591e-08, -1.15341879e-07, -3.24999563e-07,  7.53394531e-07],      dtype=float64)},
#   'f_K': {'grad': {'df_dnet_poloidal_current_amperes': Array(22996169.14220196, dtype=float64),
#     'df_dnet_toroidal_current_amperes': Array(3474556.32970045, dtype=float64),
#     'df_dplasma_coil_distance': Array(1.94775991e+15, dtype=float64),
#     'df_dplasma_dofs': Array([-3.68799761e+14, -1.54353775e+14, -6.19815813e+14,  6.25865545e+14,
#            -9.23325317e+14, -1.58579244e+15,  2.25446260e+15, -7.00241887e+14,
#             2.83425319e+13,  1.49865817e+15,  2.02441662e+14, -4.06489862e+13,
#             2.87298651e+14,  1.21510919e+15,  6.48180783e+14,  3.82888124e+15,
#             7.01043570e+14, -1.31283128e+15,  1.50111525e+15,  4.67731718e+14,
#             1.12546788e+14, -1.50717165e+14,  3.88654765e+13,  8.30989802e+14,
#            -1.08718024e+13, -2.41583720e+15, -7.60693993e+15,  7.67531560e+14,
#             4.04484524e+14, -1.06102976e+15,  1.31544759e+14,  6.66065704e+14,
#             4.80213579e+14, -4.25773778e+14, -3.32346659e+14, -2.24279464e+15,
#             1.30133371e+15,  1.00927267e+16, -2.38207493e+15, -2.77271182e+13,
#             1.81469704e+14,  1.02612473e+15,  2.25193407e+14, -5.82035965e+14,
#             6.65088001e+13,  2.88281362e+13,  1.63455944e+15, -1.41665345e+15,
#            -2.16218194e+15,  4.61397139e+15, -8.08363655e+14, -6.19929139e+14,
#            -1.21521293e+15, -7.87334388e+14, -5.80911593e+13, -5.73543897e+14,
#             7.08365202e+14, -2.13595564e+14, -1.71039206e+15,  5.01511889e+15,
#            -3.36049727e+15, -7.89596022e+13, -1.36123499e+15,  1.47778160e+15,
#             1.06486310e+15, -2.21356832e+14,  8.55752971e+14, -4.31654251e+14,
#            -6.33743476e+14, -2.07177254e+15,  2.38354038e+15,  6.53683999e+15,
#            -1.63391382e+14,  1.52417088e+14, -7.74717916e+14, -1.95508161e+13,
#            -5.16089632e+14, -3.12735719e+14, -1.00668508e+14, -5.69285425e+14,
#             1.25980600e+15,  2.44495834e+15, -8.53894289e+14, -2.52666222e+14,
#            -2.75011980e+14,  9.95525259e+13, -4.81728172e+14,  4.50689612e+14,
#             1.80698155e+14, -9.40953276e+13,  5.16765805e+14,  4.77180031e+14,
#            -5.86000339e+14, -1.40713492e+15, -7.19308553e+13, -8.73537334e+14,
#            -4.32145702e+14, -9.59510570e+14,  5.93578772e+14, -1.78875367e+14,
#            -1.80219382e+15, -5.25126206e+14, -5.65534208e+14, -4.45062190e+14,
#            -2.39219726e+14, -8.65481694e+14,  1.99867885e+15,  2.69540127e+15,
#             1.51355173e+15, -9.70737594e+14, -4.99112315e+13,  2.26388485e+15,
#             3.11067255e+14,  9.83266166e+13,  1.25569811e+14,  1.96567004e+14,
#             1.55457680e+15, -5.16359143e+14, -3.32005971e+15,  2.13632861e+15,
#             1.29311708e+15,  3.73929200e+14, -1.28120143e+15,  7.48140797e+14,
#             7.19082346e+14, -1.89167848e+14,  2.73024766e+14, -1.04799817e+13,
#            -1.07348860e+15,  2.85707258e+15, -7.85155347e+15, -1.39797914e+15,
#             7.34956978e+14,  1.47816975e+15, -7.76851992e+14,  6.26154433e+14,
#             8.75083590e+14, -2.94936471e+13, -5.65603179e+14, -1.31618197e+14,
#             9.36154885e+14, -5.99901206e+14,  5.25404079e+14, -2.89931491e+14,
#             3.65670551e+14, -2.03832299e+14, -1.42535842e+14,  5.80217604e+13,
#            -7.49427298e+14,  4.71591229e+14,  5.40604833e+14, -3.88848963e+14,
#             1.67616103e+15, -4.87624959e+15, -1.33906488e+14, -1.18004149e+15,
#             1.14585404e+15, -7.42531303e+14, -8.79046509e+14,  4.05617539e+14,
#            -3.33535928e+13, -4.90329405e+13, -2.18673697e+15,  3.05506580e+15,
#             4.14013346e+15, -3.46967812e+14, -1.47539150e+14, -5.03149834e+13,
#             5.98595420e+14, -9.24087626e+13, -6.91102429e+13,  4.07248792e+13,
#             2.92958793e+14, -1.09375693e+14, -8.79091924e+14,  1.76546462e+15,
#            -2.25286443e+14,  8.44879400e+12, -3.53583350e+14, -4.14985902e+14,
#             2.49243227e+13,  6.42235481e+13,  8.53479605e+13, -4.20139284e+14,
#            -1.38117451e+13,  1.58203421e+15, -4.43996853e+14], dtype=float64)},
#    'value': Array(1.36649691e+14, dtype=float64),
#    'vihp': Array([ 4.25284916e+13,  2.13316879e+14, -3.96632994e+14,  2.18638200e+14,
#            7.64370298e+13, -3.55432800e+14,  1.73409419e+14,  3.30734122e+13,
#            5.63732578e+13,  1.56680669e+13, -1.14697159e+14,  4.41731687e+14,
#           -3.27520010e+14,  1.32578979e+14,  1.23639458e+14, -2.07173126e+14,
#           -1.00538778e+13,  7.23029637e+12,  1.89890210e+13,  1.68859412e+13,
#           -4.52498416e+14,  5.25284198e+14, -2.87107445e+14,  3.91924038e+13,
#            1.48315499e+14,  1.49361635e+13,  1.61900598e+13,  1.07730629e+13,
#            6.20801170e+13,  2.96858628e+14, -8.85290023e+14,  2.20682926e+14,
#           -6.65412755e+13, -3.23875983e+13,  1.03088118e+12, -1.28082830e+12,
#           -2.88052671e+13,  9.75881489e+12, -3.90275864e+14,  9.22071776e+14],      dtype=float64)},
#   'hess_cond': Array(245.88424967, dtype=float64)},
#  <quadcoil.quadcoil_params.QuadcoilParams at 0x7f5c0c5c5f10>,
#  {'phi': Array([ -90313.8051487 ,  -30717.18691579,  -14025.32696776,
#            25418.03904911,   16544.46989428,   -5978.61382222,
#            -6183.10053268,  -71786.82005536,   25171.6934306 ,
#           206124.71183122,   54946.86966589,   57343.76946124,
#           -22852.59894114,  -10279.57788425,   -5481.08950263,
#             -655.67531818,   37046.77684625,  123219.49361365,
#          -374771.48236719,  -66149.8576943 ,  -54117.85831654,
#             8078.88834874,    5534.52844921,    3914.87830341,
#            18610.55974638,   -2593.38514338, -103430.73708613,
#            75511.07206356,  233428.04348702,  -23403.50613963,
#           -49767.19328034,    1681.12618803,   -6099.62605781,
#            -2905.24811532,  -22041.63820783,   35520.59594964,
#            28684.30177341,  -82130.40643713,  -92041.29371118,
#           115767.96665829], dtype=float64)},
#  {'inner_fin_df': Array(9.65129018e-13, dtype=float64),
#   'inner_fin_du': Array(4.07231401e-07, dtype=float64),
#   'inner_fin_dx_scaled': Array(5.41534634e-07, dtype=float64),
#   'inner_fin_f': Array(0.00887582, dtype=float64),
#   'inner_fin_niter': Array(72, dtype=int32),
#   'inner_fin_x': Array([-0.09587124, -0.03260736, -0.01488837,  0.02698213,  0.01756253,
#          -0.00634651, -0.00656358, -0.0762042 ,  0.02672063,  0.21880854,
#           0.05832801,  0.0608724 , -0.02425883, -0.01091213, -0.00581837,
#          -0.00069602,  0.03932644,  0.13080177, -0.39783295, -0.07022037,
#          -0.05744799,  0.00857602,  0.00587509,  0.00415578,  0.01975576,
#          -0.00275297, -0.10979532,  0.08015763,  0.24779198, -0.02484363,
#          -0.0528296 ,  0.00178457, -0.00647496, -0.00308402, -0.02339796,
#           0.03770635,  0.03044938, -0.08718428, -0.09770503,  0.12289172],      dtype=float64)})
