# %% [markdown]
# # Dipole
# This example reproduces the topology constraint.

# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
from quadcoil import quadcoil, tree_len

from simsopt.mhd import Vmec
from simsopt import load
from simsopt.field import CurrentPotentialFourier, CurrentPotentialSolve
import jax
import os
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
from jax import block_until_ready, devices, config
import time
devices()
# Out:
# [CudaDevice(id=0), CudaDevice(id=1)]

# %% [markdown]
# ## Loading files

# %%
# Loading muse++ equilibrium into VMEC
# filename_pp = "wout_muse++.nc"
# equil_pp = Vmec(filename_pp, keep_all_files=True)
# plasma_surface = equil_pp.boundary
# net_poloidal_current_amperes = equil_pp.external_current()

# Loading NCSX
winding_surface, plasma_surface = load('surfaces.json')
net_poloidal_current_amperes = 11884578.094260072
mpol = 4
ntor = 4
jax.config.update('jax_enable_x64', True)

# %% [markdown]
# # Problem settings

# %%
# Settings 
separation = 0.1
mpol = 12
ntor = 12
nfp = plasma_surface.nfp
plasma_M_theta = 16
plasma_N_phi = 32

# %% [markdown]
# ## Running a REGCOIL scan

# %%
if not os.path.exists('regcoil.npy'):
    # We scan the REGCOIL regularization factor and recover the 
    # dipole distribution Caoxiang's paper chose
    f_B_test_list = []
    phi_test_list = []
    f_K_test_list = []
    time_quadcoil_list = []
    time_regcoil_list = []
    phi_ans_list = []
    f_B_ans_list = []
    f_K_ans_list = []
    for i in jnp.append(10**np.linspace(-10, -20, 20), 0.):
        # Run QUADCOIL first
        time1 = time.time()
        regcoili_out_dict, regcoili_qp, regcoil1_dofs, status = quadcoil(
            nfp=plasma_surface.nfp,
            stellsym=plasma_surface.stellsym,
            mpol=mpol,
            ntor=ntor,
            plasma_dofs=plasma_surface.get_dofs(),
            plasma_mpol=plasma_surface.mpol,
            plasma_ntor=plasma_surface.ntor,
            net_poloidal_current_amperes=net_poloidal_current_amperes,
            net_toroidal_current_amperes=0.,
            plasma_coil_distance=separation,
            objective_name=('f_B', 'f_K'),
            objective_weight=np.array([1., i]),
            objective_unit=(1., 1.),
            metric_name=('f_B', 'f_K'),
        )
    
        phi_test_list.append(regcoil1_dofs)
        f_B_test_list.append(regcoili_out_dict['f_B']['value'])
        f_K_test_list.append(regcoili_out_dict['f_K']['value'])
        time2 = time.time()
        time_quadcoil_list.append(time2-time1)
        print('i =', i, '| time =', time2-time1)
    
        wsi = regcoili_qp.winding_surface.to_simsopt()
        psi = regcoili_qp.plasma_surface.to_simsopt()
        cpi = CurrentPotentialFourier(
            wsi, mpol=mpol, ntor=ntor,
            net_poloidal_current_amperes=net_poloidal_current_amperes,
            net_toroidal_current_amperes=0.,
            stellsym=True)
        cpsti = CurrentPotentialSolve(cpi, psi, 0)
        regcoil1_dofs_ans, regcoili_f_B_ans, regcoili_f_K_ans = cpsti.solve_tikhonov(i)
        time2 = time.time()
        time_regcoil_list.append(time2-time1)
        phi_ans_list.append(regcoil1_dofs_ans)
        f_B_ans_list.append(regcoili_f_B_ans)
        f_K_ans_list.append(regcoili_f_K_ans)
        
    print('QUADCOIL avg time:', np.average(time_quadcoil_list), '(s)')
    print('QUADCOIL max time:', np.max(time_quadcoil_list), '(s)')
    print('REGCOIL avg time:', np.average(time_regcoil_list), '(s)')
    print('REGCOIL max time:', np.max(time_regcoil_list), '(s)')
    time_regcoil_list = np.array(time_regcoil_list)
    phi_ans_list = np.array(phi_ans_list)
    f_B_ans_list = np.array(f_B_ans_list)
    f_K_ans_list = np.array(f_K_ans_list)
    time_quadcoil_list = np.array(time_quadcoil_list)
    phi_test_list = np.array(phi_test_list)
    f_B_test_list = np.array(f_B_test_list)
    f_K_test_list = np.array(f_K_test_list)
    jnp.save('regcoil.npy',{
        'regcoili_qp': regcoili_qp,
        'time_regcoil_list': time_regcoil_list,
        'phi_ans_list': phi_ans_list,
        'f_B_ans_list': f_B_ans_list,
        'f_K_ans_list': f_K_ans_list,
        'time_quadcoil_list': time_quadcoil_list,
        'phi_test_list': phi_test_list,
        'f_B_test_list': f_B_test_list,
        'f_K_test_list': f_K_test_list,
    })
    # Is quadcoil really well-behaved than regcoil?
    print('Quadcoil seems to be more well-behaved than regcoil.')    
    from quadcoil.quantity import f_B
    print('quadcoil f_B', f_B(regcoili_qp, phi_test_list[0]))
    print('regcoil  f_B', f_B(regcoili_qp, phi_ans_list[0]))
    plt.plot(phi_test_list[0], label='regcoil')
    plt.plot(phi_ans_list[0], label='quadcoil', linestyle='dashed')
    plt.legend()
    plt.show()
else:
    dict = jnp.load('regcoil.npy', allow_pickle=True).item()
    regcoili_qp = dict['regcoili_qp']
    time_regcoil_list = dict['time_regcoil_list']
    phi_ans_list = dict['phi_ans_list']
    f_B_ans_list = dict['f_B_ans_list']
    f_K_ans_list = dict['f_K_ans_list']
    time_quadcoil_list = dict['time_quadcoil_list']
    phi_test_list = dict['phi_test_list']
    f_B_test_list = dict['f_B_test_list']
    f_K_test_list = dict['f_K_test_list']

# %%
# inflection point
i_infl = 8 # np.argmin(f_K_test_list * f_B_test_list)
plt.figure(figsize=(5,3))
plt.plot(f_K_test_list, f_B_test_list, label='QUADCOIL')
plt.plot(f_K_ans_list, f_B_ans_list, label='REGCOIL')
plt.ylabel('$f_B(T^2m^2)$')
plt.xlabel('$f_K(A^2m^2)$')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.scatter(f_K_test_list[i_infl], f_B_test_list[i_infl])
print('f_K at the inflection point:', f_K_test_list[i_infl])
print('f_B at the inflection point:', f_B_test_list[i_infl])
f_B_target = f_B_test_list[i_infl]
phi_regcoil = phi_test_list[i_infl]
# Out:
# f_K at the inflection point: 27605936000000.0
# f_B at the inflection point: 0.0010883488

# %% [markdown]
# ## Dipole layer thickness optimization
# Here, we constrain the field error, and target the maximum
# magnitude of the dipole density over the surface

# %%
# Calculating normalization factors
from quadcoil.quantity import f_max_Phi2, f_B, f_max_Phi, Phi, f_l1_Phi, f_max_Phi4
# Auto-normalization will not work for dipole objectives,
# because they are zero when Phi is 0.
# Therefore, we choose instead to normalize
# using the Phi measured from the inflection point.
unit_Phi2 = f_max_Phi2(regcoili_qp, phi_test_list[i_infl])
print('Max(Phi^2) =', unit_Phi2, 'At the inflection point.')
unit_Phi4 = f_max_Phi4(regcoili_qp, phi_test_list[i_infl])
print('Max(Phi^4) =', unit_Phi4, 'At the inflection point.')
unit_Phi = f_max_Phi(regcoili_qp, phi_test_list[i_infl])
print('Max(Phi) =', unit_Phi, 'At the inflection point.')
# unit_l1 = f_l1_Phi(regcoili_qp, phi_test_list[i_infl])
# print('||Phi||1) =', unit_l1, 'At the inflection point.')
# Out:
# Max(Phi^2) = 88738900000.0 At the inflection point.
# Max(Phi^4) = 7.874592e+21 At the inflection point.
# Max(Phi) = 297890.75 At the inflection point.

# %%
time1=time.time()
# Solving with the quadcoil default function
out_dict, qp, dofs, status = quadcoil(
    nfp=plasma_surface.nfp,
    stellsym=plasma_surface.stellsym,
    plasma_coil_distance=separation,
    mpol=mpol,
    ntor=ntor,
    plasma_dofs=plasma_surface.get_dofs(),
    plasma_mpol=plasma_surface.mpol,
    plasma_ntor=plasma_surface.ntor,
    net_poloidal_current_amperes=net_poloidal_current_amperes,
    net_toroidal_current_amperes=0.,
    metric_name='f_max_Phi',
    phi_init=phi_test_list[i_infl]['phi'],
    objective_name='f_max_Phi', # Minimizing peak dipole density
    objective_unit=unit_Phi, # under an f_B constraint
    constraint_name=('f_B',),
    constraint_type=('<=',),
    constraint_unit=(f_B_target,),
    constraint_value=np.array([f_B_target,]),
    # value_only=True,
    verbose=1,
    # fstop_inner=0.,
)
jax.block_until_ready(dofs)
time2=time.time()
print('time:', time2-time1)# Run your function
# Out:
# Plasma-coil distance (m): 0.1
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi
# Objective units: 297890.75
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 0.9043905853015807
# Final Max current potential (dipole density): 119907.45201442424 (A)
# Final Avg current potential (dipole density): 2399.7714773801413 (A)
# * Total L-BFGS iteration number: 790
#     Phi scaling constant:  7857.32288693728(A)
#     Final max constraint g violation(scaled): 4.8222551507492994e-09
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 1.3382295439406599e-05
# * Last inner L_BFGS iteration number: 258
#     Inner convergence rate in x (scaled): 6.55397285197914e-11, 7.98673543689144e-11
#     Inner convergence rate in l: 2.0141555090447127e-11
#
# ----- Log barrier conversion -----
#     Objective of the final state:       0.9043905853015807
#     Objective after feasibility steps:  0.9232211850154161
#     Objective after the barrier method: 0.9109634465723693
#     Max violation of the final state:       4.8222551507492994e-09
#     Max violation after feasibility steps:  -0.016852712867733488
#     Max violation after the barrier method: -1.711609742827136e-10
# * Metric evaluated.
#     scaled x min, max = -57.32101727151808, 729.193356190017
#     f_max_Phi = 270728.3562920509
#     df_max_Phi/dy min, max: -17032112.0, 14228952.020893212
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -14228952.020893212, 17032112.0
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -5368163336192.0, 1020193973654.0267
#     d2L_k/dxdy min, max: -137069886.44675875, 19289198.404333934
#     VIHP min, max components (currently chosen): -0.00010360888996293129, 0.00022433698201169554
# ***** Hessian matrix rank and cond: 313, 2599368790145828.5
# time: 129.6095507144928

# %%
dofs_regcoil = phi_test_list[i_infl]
print('f_B from REGCOIL:      ', f_B(regcoili_qp, dofs_regcoil))
print('f_B from QUADCOIL:     ', f_B(qp, dofs))
f_Phi_ctrl = f_max_Phi(regcoili_qp,dofs_regcoil)
f_Phi_1 = f_max_Phi(qp, dofs)
print('Max dipole dens from REGCOIL:      ', f_Phi_ctrl)
print('Max dipole dens from QUADCOIL:     ', f_Phi_1, round((f_Phi_ctrl-f_Phi_1)/f_Phi_ctrl*100, 3), '% improvement')

phi_regcoil = Phi(qp, dofs_regcoil)
phi_quadcoil = Phi(qp, dofs)
cmin = np.min([phi_regcoil, phi_quadcoil])
cmax = np.max([phi_regcoil, phi_quadcoil])

fig, axes = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)

# Plot for REGCOIL
im0 = axes[0].contour(phi_regcoil, vmin=cmin, vmax=cmax, cmap = 'seismic', levels=20)
axes[0].set_title(r'REGCOIL\n$\Phi_{max}$='+str(int(f_Phi_ctrl))+'A')

# Plot for QUADCOIL
im1 = axes[1].contour(phi_quadcoil, vmin=cmin, vmax=cmax, cmap = 'seismic', levels=20)
axes[1].set_title(r'QUADCOIL\n$\Phi_{max}$='+str(int(f_Phi_1))+'A')



# Add colorbar with better positioning
cbar = fig.colorbar(im1, ax=axes, orientation='vertical', shrink=1., aspect=25, pad=0.05)
cbar.set_label("Dipole Density (A)")

plt.show()
# Out:
# f_B from REGCOIL:       0.0010883431450169736
# f_B from QUADCOIL:      0.0010883488032714602
# Max dipole dens from REGCOIL:       297890.75
# Max dipole dens from QUADCOIL:      269409.59118493204 9.561 % improvement

# %% [markdown]
# ## Dipole sparsity optimization
# Here, we constrain the field error and maximum dipole density,
# and target the L-1 norm of the dipole over the surface.

# %%
f_Phi_ctrl = f_max_Phi(regcoili_qp, phi_test_list[i_infl])

# %%
# Solving with the quadcoil default function
time1 = time.time()
l1_out_dict, l1_qp, l1_dofs, l1_status = quadcoil(
    nfp=plasma_surface.nfp,
    stellsym=plasma_surface.stellsym,
    plasma_coil_distance=separation,
    mpol=mpol,
    ntor=ntor,
    plasma_dofs=plasma_surface.get_dofs(),
    plasma_mpol=plasma_surface.mpol,
    plasma_ntor=plasma_surface.ntor,
    net_poloidal_current_amperes=net_poloidal_current_amperes,
    net_toroidal_current_amperes=0.,
    metric_name='f_B',
    objective_name='f_l1_Phi', # Minimizing the L1 norm of Phi
    objective_unit=unit_l1, # under an f_B, max Phi constraint
    constraint_name=('f_B', 'f_max_Phi',),
    constraint_type=('<=', '<=',),
    constraint_unit=(f_B_target, f_Phi_ctrl,),
    constraint_value=np.array([f_B_target, f_Phi_ctrl,]),
    value_only=True
    # verbose=3,
    # **numerical_kwargs
)
time2 = time.time()
print(time2-time1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 16
#       1 # Solving with the quadcoil default function
#       2 time1 = time.time()
#       3 l1_out_dict, l1_qp, l1_dofs, l1_status = quadcoil(
#       4     nfp=plasma_surface.nfp,
#       5     stellsym=plasma_surface.stellsym,
#       6     plasma_coil_distance=separation,
#       7     mpol=mpol,
#       8     ntor=ntor,
#       9     plasma_dofs=plasma_surface.get_dofs(),
#      10     plasma_mpol=plasma_surface.mpol,
#      11     plasma_ntor=plasma_surface.ntor,
#      12     net_poloidal_current_amperes=net_poloidal_current_amperes,
#      13     net_toroidal_current_amperes=0.,
#      14     metric_name='f_B',
#      15     objective_name='f_l1_Phi', # Minimizing the L1 norm of Phi
# ---> 16     objective_unit=unit_l1, # under an f_B, max Phi constraint
#      17     constraint_name=('f_B', 'f_max_Phi',),
#      18     constraint_type=('<=', '<=',),
#      19     constraint_unit=(f_B_target, f_Phi_ctrl,),
#      20     constraint_value=np.array([f_B_target, f_Phi_ctrl,]),
#      21     value_only=True
#      22     # verbose=3,
#      23     # **numerical_kwargs
#      24 )
#      25 time2 = time.time()
#      26 print(time2-time1)
#
# NameError: name 'unit_l1' is not defined

# %%
print('f_B from REGCOIL:      ', f_B(regcoili_qp, phi_test_list[i_infl]))
print('f_B from QUADCOIL:     ', f_B(l1_qp, l1_dofs))
f_l1_Phi_crtl = f_l1_Phi(regcoili_qp, phi_test_list[i_infl])
f_l1_Phi_l1 = f_l1_Phi(l1_qp, l1_dofs)
print('Max dipole dens from REGCOIL:      ', f_l1_Phi_crtl)
print('Max dipole dens from QUADCOIL:     ', f_l1_Phi_l1, round((f_l1_Phi_crtl-f_l1_Phi_l1)/f_l1_Phi_crtl*100, 3), '% improvement')

phi_regcoil = Phi(regcoili_qp, phi_test_list[i_infl])
phi_quadcoil_l1 = Phi(l1_qp, l1_dofs)
cmin = np.min([phi_regcoil, phi_quadcoil_l1])
cmax = np.max([phi_regcoil, phi_quadcoil_l1])

fig, axes = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)

# Plot for REGCOIL
im0 = axes[0].contour(phi_regcoil, vmin=cmin, vmax=cmax, cmap = 'seismic', levels=20)
axes[0].set_title('REGCOIL')

# Plot for QUADCOIL
im1 = axes[1].contour(phi_quadcoil_l1, vmin=cmin, vmax=cmax, cmap = 'seismic', levels=20)
axes[1].set_title('QUADCOIL')



# Add colorbar with better positioning
cbar = fig.colorbar(im1, ax=axes, orientation='vertical', shrink=1., aspect=25, pad=0.05)
cbar.set_label("Dipole Density (A)")

plt.show()

# %% [markdown]
# ### Cumulative distribution function plot
# This plot shows the proportion of grid points
# with dipole density $\leq x\% \Phi_{max}$.

# %%
# Flatten arrays
phi_reg = jnp.abs(phi_regcoil.flatten())
phi_quad = jnp.abs(phi_quadcoil_l1.flatten())

# Sort values
phi_reg_sorted = np.sort(phi_reg) / np.max(phi_reg) * 100
phi_quad_sorted = np.sort(phi_quad) / np.max(phi_reg) *100

# Compute CCDFs
ccdf_reg = np.arange(1, len(phi_reg_sorted)+1) / len(phi_reg_sorted)*100
ccdf_quad = np.arange(1, len(phi_quad_sorted)+1) / len(phi_quad_sorted)*100

# Plot
plt.figure(figsize=(5, 3))
plt.plot(phi_reg_sorted, ccdf_reg, label='REGCOIL', color='blue')
plt.plot(phi_quad_sorted, ccdf_quad, label='QUADCOIL', color='orange')
plt.xticks(np.linspace(0, 100, 11))
# Labels and legend
plt.xlabel('Dipole density, as % of $\Phi_{max}$ (A)')
plt.ylabel('CDF (% $\leq$ x)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
i = jnp.linspace(-0.1, 0.1, 50)[0]
plasma_dof_i = plasma_surface.get_dofs().copy()
plasma_dof_i[0] *= (1 + i)
out_dict_i, qp_i, dofs_i, status_i = quadcoil(
    nfp=plasma_surface.nfp,
    stellsym=plasma_surface.stellsym,
    plasma_coil_distance=separation,
    mpol=mpol,
    ntor=ntor,
    plasma_dofs=plasma_dof_i,
    plasma_mpol=plasma_surface.mpol,
    plasma_ntor=plasma_surface.ntor,
    net_poloidal_current_amperes=net_poloidal_current_amperes,
    net_toroidal_current_amperes=0.,
    metric_name=('f_max_Phi', 'f_K', 'f_B'),
    objective_name='f_max_Phi', # Minimizing peak dipole density
    objective_unit=unit_Phi, # under an f_B constraint
    constraint_name=('f_B',),
    constraint_type=('<=',),
    constraint_unit=(f_B_target,),
    constraint_value=np.array([f_B_target,]),
    verbose=0,
    # **numerical_kwargs
)
print('f_B!!!!!!!', f_B(qp_i, dofs_i))

# %% [markdown]
# ## Taylor test for dipole thickness optimization

# %%
plasma_dof_0_list = []
phi_test_list = []
f_max_Phi_test_list = []
f_max_Phi_diff_test_list = []
f_K_test_list = []
f_B_test_list = []
f_K_diff_test_list = []
time_quadcoil_list = []
time_regcoil_list = []
lam_list = []
mu_list = []
c_list = []
qp_list = []
for i in jnp.linspace(-0.1, 0.1, 50):
    plasma_dof_i = plasma_surface.get_dofs().copy()
    plasma_dof_i[0] *= (1 + i)
    # Run QUADCOIL first
    time1 = time.time()

    out_dict_i, qp_i, dofs_i, status_i = quadcoil(
        nfp=plasma_surface.nfp,
        stellsym=plasma_surface.stellsym,
        plasma_coil_distance=separation,
        mpol=mpol,
        ntor=ntor,
        plasma_dofs=plasma_dof_i,
        plasma_mpol=plasma_surface.mpol,
        plasma_ntor=plasma_surface.ntor,
        net_poloidal_current_amperes=net_poloidal_current_amperes,
        net_toroidal_current_amperes=0.,
        metric_name=('f_max_Phi', 'f_K', 'f_B'),
        objective_name='f_max_Phi2', # Minimizing peak dipole density
        objective_unit=unit_Phi2, # under an f_B constraint
        constraint_name=('f_B',),
        constraint_type=('<=',),
        constraint_unit=(f_B_target,),
        constraint_value=np.array([f_B_target,]),
        verbose=1,
        # **numerical_kwargs
    )
    qp_list.append(qp_i)
    block_until_ready(dofs_i)
    block_until_ready(out_dict_i)
    block_until_ready(qp_i)
    time2 = time.time()
    time_quadcoil_list.append(time2-time1)
    print('time:', time2-time1)
    # REGCOIL ---------------------------------------------------
    plasma_dof_0_list.append(plasma_dof_i[0])
    phi_test_list.append(dofs_i)
    f_max_Phi_test_list.append(out_dict_i['f_max_Phi']['value'])
    f_max_Phi_diff_test_list.append(out_dict_i['f_max_Phi']['grad']['df_dplasma_dofs'][0])
    f_K_test_list.append(out_dict_i['f_K']['value'])
    f_B_test_list.append(out_dict_i['f_B']['value'])
    f_K_diff_test_list.append(out_dict_i['f_K']['grad']['df_dplasma_dofs'][0])
    lam_list.append(status_i['inner_fin_lam'])
    mu_list.append(status_i['inner_fin_mu'])
    c_list.append(status_i['inner_fin_c'])
print('QUADCOIL avg time:', np.average(time_quadcoil_list), '(s)')
print('QUADCOIL max time:', np.max(time_quadcoil_list), '(s)')
# Out:
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.2438974141092598
# Final Max current potential (dipole density): 146198.91000502382 (A)
# Final Avg current potential (dipole density): 2966.5923180325112 (A)
# * Total L-BFGS iteration number: 415
#     Phi scaling constant:  262567.1990245836(A)
#     Final max constraint g violation(scaled): 1.2863689224928976e-08
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 4.497862985278262e-09
# * Last inner L_BFGS iteration number: 8
#     Inner convergence rate in x (scaled): 9.09678910341274e-11, 1.6709418712780546e-10
#     Inner convergence rate in l: 1.5097292305199517e-09
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.2438974141092598
#     Objective after feasibility steps:  1.2505715623808493
#     Objective after the barrier method: 1.247283491083815
#     Max violation of the final state:       1.2863689224928976e-08
#     Max violation after feasibility steps:  -0.002323689170624421
#     Max violation after the barrier method: -0.000686418954975343
# ***** Hessian matrix rank and cond: 1, 1.8051109135569037e+18
# ***** Hessian matrix rank and cond: 1, 1.8051109135569037e+18
# ***** Hessian matrix rank and cond: 1, 1.8051109135569037e+18
# ***** Hessian matrix2 rank and cond: 2, 6.343365789538337e+16
# ***** Hessian matrix2 rank and cond: 2, 6.343365789538337e+16
# ***** Hessian matrix2 rank and cond: 2, 6.343365789538337e+16
# * Metric evaluated.
#     scaled x min, max = -797.684599853746, 7916.3269262895155
#     f_B = 0.0010871319024306208
#     df_B/dy min, max: -0.008505062558095383, 0.9587281346321106
#     1st term (df_B/dx* dx*/dy) min, max: -0.9587281346321106, 0.23963936680808065
#     2nd term (df_B/dy) min, max:         -0.2058130157185861, 0.24990096330690537
#     dL_k/dy min, max:    -821762.25, 205359.18212387114
#     d2L_k/dxdy min, max: -1518492445.7193153, 134678018.0254943
#     VIHP min, max components (currently chosen): -5.092311512547395e-07, 3.435074334672764e-08
# * Metric evaluated.
#     scaled x min, max = -797.684599853746, 7916.3269262895155
#     f_max_Phi = 332485.4132714723
#     df_max_Phi/dy min, max: -6074537.0, 1591682.56793858
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -1591682.56793858, 6074537.0
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -821762.25, 205359.18212387114
#     d2L_k/dxdy min, max: -1518492445.7193153, 134678018.0254943
#     VIHP min, max components (currently chosen): -30.051431476176944, 16.583957032447515
# * Metric evaluated.
#     scaled x min, max = -797.684599853746, 7916.3269262895155
#     f_K = 31691120729851.688
#     df_K/dy min, max: -153148295714340.8, 263837072752640.0
#     1st term (df_K/dx* dx*/dy) min, max: -263837072752640.0, 160629876627920.97
#     2nd term (df_K/dy) min, max:         -21287607222334.97, 54445025911584.82
#     dL_k/dy min, max:    -821762.25, 205359.18212387114
#     d2L_k/dxdy min, max: -1518492445.7193153, 134678018.0254943
#     VIHP min, max components (currently chosen): -16643430112.163376, 51298246026.61329
# time: 143.24370574951172
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.221964568533442
# Final Max current potential (dipole density): 144965.1156689279 (A)
# Final Avg current potential (dipole density): 2939.110673569975 (A)
# * Total L-BFGS iteration number: 416
#     Phi scaling constant:  260051.56084264183(A)
#     Final max constraint g violation(scaled): 4.222643124052183e-09
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 1.1272726226073775e-08
# * Last inner L_BFGS iteration number: 20
#     Inner convergence rate in x (scaled): 8.100851628098181e-11, 5.971334623413204e-10
#     Inner convergence rate in l: 3.9805070350951155e-10
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.221964568533442
#     Objective after feasibility steps:  1.228052382035786
#     Objective after the barrier method: 1.2247124660069688
#     Max violation of the final state:       4.222643124052183e-09
#     Max violation after feasibility steps:  -0.0009782711382395615
#     Max violation after the barrier method: -0.00043581694492877965
# ***** Hessian matrix rank and cond: 1, 5.9050819637181964e+19
# ***** Hessian matrix rank and cond: 1, 5.9050819637181964e+19
# ***** Hessian matrix rank and cond: 1, 5.9050819637181964e+19
# ***** Hessian matrix2 rank and cond: 2, 1.3143833456225293e+17
# ***** Hessian matrix2 rank and cond: 2, 1.3143833456225293e+17
# ***** Hessian matrix2 rank and cond: 2, 1.3143833456225293e+17
# * Metric evaluated.
#     scaled x min, max = -1037.0439070186487, 7988.925789929495
#     f_B = 0.0010865181254762673
#     df_B/dy min, max: -0.026055322136236653, 0.8711237907409668
#     1st term (df_B/dx* dx*/dy) min, max: -0.8711237907409668, 0.21589895525505676
#     2nd term (df_B/dy) min, max:         -0.20411351717111864, 0.2474971607526056
#     dL_k/dy min, max:    -546246.9375, 135194.5639004036
#     d2L_k/dxdy min, max: -3997566561.1277394, 128641288.01528728
#     VIHP min, max components (currently chosen): -1.083899904926914e-06, 1.058900607153523e-07
# * Metric evaluated.
#     scaled x min, max = -1037.0439070186487, 7988.925789929495
#     f_max_Phi = 329536.11985103716
#     df_max_Phi/dy min, max: -3405551.25, 871935.9241011845
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -871935.9241011845, 3405551.25
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -546246.9375, 135194.5639004036
#     d2L_k/dxdy min, max: -3997566561.1277394, 128641288.01528728
#     VIHP min, max components (currently chosen): -51.70677619119852, 15.28983363660289
# * Metric evaluated.
#     scaled x min, max = -1037.0439070186487, 7988.925789929495
#     f_K = 31518343709427.22
#     df_K/dy min, max: -164043350514338.78, 154961709970496.12
#     1st term (df_K/dx* dx*/dy) min, max: -125242792666397.66, 163593118775962.56
#     2nd term (df_K/dy) min, max:         -21178278240344.43, 54219367100785.16
#     dL_k/dy min, max:    -546246.9375, 135194.5639004036
#     d2L_k/dxdy min, max: -3997566561.1277394, 128641288.01528728
#     VIHP min, max components (currently chosen): -24861528106.97394, 68098471185.466484
# time: 66.66330766677856
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.2004890348171606
# Final Max current potential (dipole density): 143746.49233676202 (A)
# Final Avg current potential (dipole density): 2911.584919495147 (A)
# * Total L-BFGS iteration number: 426
#     Phi scaling constant:  257573.7686812079(A)
#     Final max constraint g violation(scaled): 1.834339347084324e-10
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 1.4924027113142714e-08
# * Last inner L_BFGS iteration number: 18
#     Inner convergence rate in x (scaled): 8.561719036742164e-11, 3.255234221981697e-10
#     Inner convergence rate in l: 1.3977596857728258e-10
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.2004890348171606
#     Objective after feasibility steps:  1.2065500442555188
#     Objective after the barrier method: 1.2032674674451793
#     Max violation of the final state:       1.834339347084324e-10
#     Max violation after feasibility steps:  -0.0010814825099083603
#     Max violation after the barrier method: -0.0004934889722447711
# ***** Hessian matrix rank and cond: 1, 1.828780410850217e+20
# ***** Hessian matrix rank and cond: 1, 1.828780410850217e+20
# ***** Hessian matrix rank and cond: 1, 1.828780410850217e+20
# ***** Hessian matrix2 rank and cond: 2, 4.2202165542620525e+17
# ***** Hessian matrix2 rank and cond: 2, 4.2202165542620525e+17
# ***** Hessian matrix2 rank and cond: 2, 4.2202165542620525e+17
# * Metric evaluated.
#     scaled x min, max = -1168.4048196790982, 7801.333820869008
#     f_B = 0.001087551631069206
#     df_B/dy min, max: -0.005354428357410457, 0.9739243388175964
#     1st term (df_B/dx* dx*/dy) min, max: -0.9739243388175964, 0.23930564839194005
#     2nd term (df_B/dy) min, max:         -0.2024533910805276, 0.24554991324657635
#     dL_k/dy min, max:    -1254440.25, 308027.68793164904
#     d2L_k/dxdy min, max: -7590625010.129694, 66174762.45334535
#     VIHP min, max components (currently chosen): -2.2526130418914813e-07, 2.943987263222653e-08
# * Metric evaluated.
#     scaled x min, max = -1168.4048196790982, 7801.333820869008
#     f_max_Phi = 326619.9297764589
#     df_max_Phi/dy min, max: -3389261.5, 817782.3192213759
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -817782.3192213759, 3389261.5
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1254440.25, 308027.68793164904
#     d2L_k/dxdy min, max: -7590625010.129694, 66174762.45334535
#     VIHP min, max components (currently chosen): -10.50925100540338, 11.948093474958581
# * Metric evaluated.
#     scaled x min, max = -1168.4048196790982, 7801.333820869008
#     f_K = 31348433127492.4
#     df_K/dy min, max: -319472807664526.1, 483393018365729.0
#     1st term (df_K/dx* dx*/dy) min, max: -482797453695889.06, 318446502072686.9
#     2nd term (df_K/dy) min, max:         -21073769906928.53, 53999610821820.414
#     dL_k/dy min, max:    -1254440.25, 308027.68793164904
#     d2L_k/dxdy min, max: -7590625010.129694, 66174762.45334535
#     VIHP min, max components (currently chosen): -28480179671.439877, 25839977322.547054
# time: 65.62484383583069
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.1794596577184508
# Final Max current potential (dipole density): 142543.2073952858 (A)
# Final Avg current potential (dipole density): 2884.885656138036 (A)
# * Total L-BFGS iteration number: 385
#     Phi scaling constant:  255133.08525424916(A)
#     Final max constraint g violation(scaled): 3.4885291100295035e-08
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 8.38661737154253e-08
# * Last inner L_BFGS iteration number: 31
#     Inner convergence rate in x (scaled): 6.331512903708957e-11, 1.7158875913421286e-10
#     Inner convergence rate in l: 4.940714504186872e-12
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.1794596577184508
#     Objective after feasibility steps:  1.1854630652885183
#     Objective after the barrier method: 1.182300195559212
#     Max violation of the final state:       3.4885291100295035e-08
#     Max violation after feasibility steps:  -0.0011573071476214114
#     Max violation after the barrier method: -0.0005775733783313086
# ***** Hessian matrix rank and cond: 1, 6.074079926679351e+19
# ***** Hessian matrix rank and cond: 1, 6.074079926679351e+19
# ***** Hessian matrix rank and cond: 1, 6.074079926679351e+19
# ***** Hessian matrix2 rank and cond: 2, 4.0666938755346874e+17
# ***** Hessian matrix2 rank and cond: 2, 4.0666938755346874e+17
# ***** Hessian matrix2 rank and cond: 2, 4.0666938755346874e+17
# * Metric evaluated.
#     scaled x min, max = -1022.8595699868309, 7563.539999933082
#     f_B = 0.0010875101815278705
#     df_B/dy min, max: -0.005599179651155334, 0.9720454216003418
#     1st term (df_B/dx* dx*/dy) min, max: -0.9720454216003418, 0.23684825539283025
#     2nd term (df_B/dy) min, max:         -0.2009477238034138, 0.24360629386040666
#     dL_k/dy min, max:    -1192438.125, 290485.459797114
#     d2L_k/dxdy min, max: -7370471610.907828, 457106843.4072176
#     VIHP min, max components (currently chosen): -2.438849408818068e-07, 2.890545408809334e-08
# * Metric evaluated.
#     scaled x min, max = -1022.8595699868309, 7563.539999933082
#     f_max_Phi = 323735.36752081354
#     df_max_Phi/dy min, max: -4615877.0, 1122837.0406611885
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -1122837.0406611885, 4615877.0
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1192438.125, 290485.459797114
#     d2L_k/dxdy min, max: -7370471610.907828, 457106843.4072176
#     VIHP min, max components (currently chosen): -9.130287804991012, 18.18055835003563
# * Metric evaluated.
#     scaled x min, max = -1022.8595699868309, 7563.539999933082
#     f_K = 31182077508099.69
#     df_K/dy min, max: -187677793560776.4, 368842899456000.0
#     1st term (df_K/dx* dx*/dy) min, max: -368842899456000.0, 187224009834882.88
#     2nd term (df_K/dy) min, max:         -20966822200324.8, 53779558940611.24
#     dL_k/dy min, max:    -1192438.125, 290485.459797114
#     d2L_k/dxdy min, max: -7370471610.907828, 457106843.4072176
#     VIHP min, max components (currently chosen): -26387677556.286366, 8945143172.041742
# time: 66.2013463973999
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.1588660591622573
# Final Max current potential (dipole density): 141354.87634197116 (A)
# Final Avg current potential (dipole density): 2859.2467082347684 (A)
# * Total L-BFGS iteration number: 411
#     Phi scaling constant:  252728.79126179(A)
#     Final max constraint g violation(scaled): 2.3128923221094055e-09
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 1.969379321699031e-08
# * Last inner L_BFGS iteration number: 36
#     Inner convergence rate in x (scaled): 9.800565844394418e-11, 2.6302150923783593e-10
#     Inner convergence rate in l: 8.166045617485906e-11
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.1588660591622573
#     Objective after feasibility steps:  1.1645922277548288
#     Objective after the barrier method: 1.16132135927418
#     Max violation of the final state:       2.3128923221094055e-09
#     Max violation after feasibility steps:  -0.0016874412891461077
#     Max violation after the barrier method: -0.0004283024468267893
# ***** Hessian matrix rank and cond: 1, 2.8623380841941233e+18
# ***** Hessian matrix rank and cond: 1, 2.8623380841941233e+18
# ***** Hessian matrix rank and cond: 1, 2.8623380841941233e+18
# ***** Hessian matrix2 rank and cond: 2, 1.5091091475574528e+17
# ***** Hessian matrix2 rank and cond: 2, 1.5091091475574528e+17
# ***** Hessian matrix2 rank and cond: 2, 1.5091091475574528e+17
# * Metric evaluated.
#     scaled x min, max = -1220.302047773935, 9384.01916558887
#     f_B = 0.0010874986502730005
#     df_B/dy min, max: -0.007049846236132334, 0.9647916555404663
#     1st term (df_B/dx* dx*/dy) min, max: -0.9647916555404663, 0.23369567927955212
#     2nd term (df_B/dy) min, max:         -0.20002790076126373, 0.24216929841588963
#     dL_k/dy min, max:    -1176264.25, 284855.0859612588
#     d2L_k/dxdy min, max: -2613324330.5816708, 185766910.3967339
#     VIHP min, max components (currently chosen): -3.009865073512898e-07, 2.6095156428545464e-08
# * Metric evaluated.
#     scaled x min, max = -1220.302047773935, 9384.01916558887
#     f_max_Phi = 320893.2511334482
#     df_max_Phi/dy min, max: -3204028.75, 785699.5907314188
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -785699.5907314188, 3204028.75
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1176264.25, 284855.0859612588
#     d2L_k/dxdy min, max: -2613324330.5816708, 185766910.3967339
#     VIHP min, max components (currently chosen): -8.123812080754107, 7.222764575580631
# * Metric evaluated.
#     scaled x min, max = -1220.302047773935, 9384.01916558887
#     f_K = 31020181291842.547
#     df_K/dy min, max: -144511824890801.0, 154786259271680.0
#     1st term (df_K/dx* dx*/dy) min, max: -154786259271680.0, 151376440904795.8
#     2nd term (df_K/dy) min, max:         -20859410873335.87, 53561913141889.59
#     dL_k/dy min, max:    -1176264.25, 284855.0859612588
#     d2L_k/dxdy min, max: -2613324330.5816708, 185766910.3967339
#     VIHP min, max components (currently chosen): -13479899576.430838, 27679143171.150345
# time: 65.90925359725952
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.1386984548830452
# Final Max current potential (dipole density): 140180.8232388356 (A)
# Final Avg current potential (dipole density): 2833.064696044562 (A)
# * Total L-BFGS iteration number: 417
#     Phi scaling constant:  250360.18484453444(A)
#     Final max constraint g violation(scaled): 1.5736616010286752e-08
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 1.1073764732113232e-07
# * Last inner L_BFGS iteration number: 40
#     Inner convergence rate in x (scaled): 7.195692574630324e-11, 1.8325261773365163e-10
#     Inner convergence rate in l: 9.317879801074014e-12
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.1386984548830452
#     Objective after feasibility steps:  1.1445286614050123
#     Objective after the barrier method: 1.1412443977051685
#     Max violation of the final state:       1.5736616010286752e-08
#     Max violation after feasibility steps:  -0.0018882232542802857
#     Max violation after the barrier method: -0.0005608141079955775
# ***** Hessian matrix rank and cond: 1, 8.746770416256665e+19
# ***** Hessian matrix rank and cond: 1, 8.746770416256665e+19
# ***** Hessian matrix rank and cond: 1, 8.746770416256665e+19
# ***** Hessian matrix2 rank and cond: 2, 4.342830041551987e+17
# ***** Hessian matrix2 rank and cond: 2, 4.342830041551987e+17
# ***** Hessian matrix2 rank and cond: 2, 4.342830041551987e+17
# * Metric evaluated.
#     scaled x min, max = -654.4330712785023, 7639.014763574005
#     f_B = 0.001087379256722542
#     df_B/dy min, max: -0.008191428118390492, 0.9592064023017883
#     1st term (df_B/dx* dx*/dy) min, max: -0.9592064023017883, 0.2311230851750144
#     2nd term (df_B/dy) min, max:         -0.19922555264770112, 0.24085778001324368
#     dL_k/dy min, max:    -1031414.125, 248424.11717130936
#     d2L_k/dxdy min, max: -7957297903.494124, 704831519.6866094
#     VIHP min, max components (currently chosen): -3.2178397302839294e-07, 1.676830643476987e-08
# * Metric evaluated.
#     scaled x min, max = -654.4330712785023, 7639.014763574005
#     f_max_Phi = 318066.76978385233
#     df_max_Phi/dy min, max: -5888879.0, 1454181.2850930078
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -1454181.2850930078, 5888879.0
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1031414.125, 248424.11717130936
#     d2L_k/dxdy min, max: -7957297903.494124, 704831519.6866094
#     VIHP min, max components (currently chosen): -20.986528392105736, 12.365685482727807
# * Metric evaluated.
#     scaled x min, max = -654.4330712785023, 7639.014763574005
#     f_K = 30857432773517.15
#     df_K/dy min, max: -202457922027474.97, 148532394171562.3
#     1st term (df_K/dx* dx*/dy) min, max: -148269294767506.84, 202625709620403.44
#     2nd term (df_K/dy) min, max:         -20756644494401.85, 53345507495018.24
#     dL_k/dy min, max:    -1031414.125, 248424.11717130936
#     d2L_k/dxdy min, max: -7957297903.494124, 704831519.6866094
#     VIHP min, max components (currently chosen): -5850808642.087128, 25456105415.353672
# time: 66.9947657585144
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.11894643044983
# Final Max current potential (dipole density): 139021.38441332607 (A)
# Final Avg current potential (dipole density): 2807.4126077694386 (A)
# * Total L-BFGS iteration number: 368
#     Phi scaling constant:  248026.58105841526(A)
#     Final max constraint g violation(scaled): 1.3188816039289009e-08
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 4.375905328145114e-09
# * Last inner L_BFGS iteration number: 11
#     Inner convergence rate in x (scaled): 9.197780276393226e-11, 2.4190678433765347e-10
#     Inner convergence rate in l: 3.9794167960849336e-11
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.11894643044983
#     Objective after feasibility steps:  1.1246434424913503
#     Objective after the barrier method: 1.1214735348136051
#     Max violation of the final state:       1.3188816039289009e-08
#     Max violation after feasibility steps:  -0.0016199461254733372
#     Max violation after the barrier method: -0.0005050881817487696
# ***** Hessian matrix rank and cond: 1, 6.281928495869895e+18
# ***** Hessian matrix rank and cond: 1, 6.281928495869895e+18
# ***** Hessian matrix rank and cond: 1, 6.281928495869895e+18
# ***** Hessian matrix2 rank and cond: 2, 1.4072678562426325e+17
# ***** Hessian matrix2 rank and cond: 2, 1.4072678562426325e+17
# ***** Hessian matrix2 rank and cond: 2, 1.4072678562426325e+17
# * Metric evaluated.
#     scaled x min, max = -1654.2393128895717, 6190.024148429754
#     f_B = 0.0010877990872689405
#     df_B/dy min, max: -0.0026034184126511317, 0.9867674112319946
#     1st term (df_B/dx* dx*/dy) min, max: -0.9867674112319946, 0.23604275971787586
#     2nd term (df_B/dy) min, max:         -0.198140925650356, 0.23916747827022675
#     dL_k/dy min, max:    -1819134.0, 435077.69107932295
#     d2L_k/dxdy min, max: -3841082204.823575, 97171343.38243206
#     VIHP min, max components (currently chosen): -9.005586894981772e-08, 9.312447240987469e-09
# * Metric evaluated.
#     scaled x min, max = -1654.2393128895717, 6190.024148429754
#     f_max_Phi = 315302.0461208091
#     df_max_Phi/dy min, max: -4585223.0, 1102654.39267131
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -1102654.39267131, 4585223.0
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1819134.0, 435077.69107932295
#     d2L_k/dxdy min, max: -3841082204.823575, 97171343.38243206
#     VIHP min, max components (currently chosen): -21.097641017654755, 9.713144324744794
# * Metric evaluated.
#     scaled x min, max = -1654.2393128895717, 6190.024148429754
#     f_K = 30698268982891.7
#     df_K/dy min, max: -113779411369709.73, 146004148311747.7
#     1st term (df_K/dx* dx*/dy) min, max: -120453676943298.66, 117408428653565.52
#     2nd term (df_K/dy) min, max:         -20651963022302.312, 53131141420957.29
#     dL_k/dy min, max:    -1819134.0, 435077.69107932295
#     d2L_k/dxdy min, max: -3841082204.823575, 97171343.38243206
#     VIHP min, max components (currently chosen): -12522856098.290287, 4405688928.1528635
# time: 64.40463066101074
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.099600439049256
# Final Max current potential (dipole density): 137876.22328621836 (A)
# Final Avg current potential (dipole density): 2782.5761861232763 (A)
# * Total L-BFGS iteration number: 394
#     Phi scaling constant:  245727.3113682703(A)
#     Final max constraint g violation(scaled): 1.2879445510094456e-08
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 3.828127271949899e-08
# * Last inner L_BFGS iteration number: 34
#     Inner convergence rate in x (scaled): 3.723244921920262e-11, 1.6472455123265207e-10
#     Inner convergence rate in l: 1.6814327707947996e-11
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.099600439049256
#     Objective after feasibility steps:  1.1053896370828862
#     Objective after the barrier method: 1.1020664775690308
#     Max violation of the final state:       1.2879445510094456e-08
#     Max violation after feasibility steps:  -0.001958201654632896
#     Max violation after the barrier method: -0.00025518439760041645
# ***** Hessian matrix rank and cond: 1, 4.295111507982416e+18
# ***** Hessian matrix rank and cond: 1, 4.295111507982416e+18
# ***** Hessian matrix rank and cond: 1, 4.295111507982416e+18
# ***** Hessian matrix2 rank and cond: 2, 1.6681032945108227e+17
# ***** Hessian matrix2 rank and cond: 2, 1.6681032945108227e+17
# ***** Hessian matrix2 rank and cond: 2, 1.6681032945108227e+17
# * Metric evaluated.
#     scaled x min, max = -1316.2950605299734, 9012.756096136916
#     f_B = 0.0010874042037601044
#     df_B/dy min, max: -0.007596241272414844, 0.9615389704704285
#     1st term (df_B/dx* dx*/dy) min, max: -0.9615389704704285, 0.22654384706428665
#     2nd term (df_B/dy) min, max:         -0.19458921814408325, 0.23563668757201603
#     dL_k/dy min, max:    -1058654.125, 249457.73760630403
#     d2L_k/dxdy min, max: -2956280740.4348083, 128748318.3202445
#     VIHP min, max components (currently chosen): -3.6224708438562447e-07, 3.022842502784242e-08
# * Metric evaluated.
#     scaled x min, max = -1316.2950605299734, 9012.756096136916
#     f_max_Phi = 312647.7680380014
#     df_max_Phi/dy min, max: -1259948.5, 320829.83634090127
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -320829.83634090127, 1259948.5
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -1058654.125, 249457.73760630403
#     d2L_k/dxdy min, max: -2956280740.4348083, 128748318.3202445
#     VIHP min, max components (currently chosen): -3.542047981250313, 3.309790944368091
# * Metric evaluated.
#     scaled x min, max = -1316.2950605299734, 9012.756096136916
#     f_K = 30541080790384.77
#     df_K/dy min, max: -187784340520601.53, 159533827832436.5
#     1st term (df_K/dx* dx*/dy) min, max: -121992504421600.92, 194242425928847.53
#     2nd term (df_K/dy) min, max:         -20542555706424.695, 52916202607890.81
#     dL_k/dy min, max:    -1058654.125, 249457.73760630403
#     d2L_k/dxdy min, max: -2956280740.4348083, 128748318.3202445
#     VIHP min, max components (currently chosen): -6953139573.231851, 22842999793.473164
# time: 68.88758683204651
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.0806511979912028
# Final Max current potential (dipole density): 136744.88545883205 (A)
# Final Avg current potential (dipole density): 2758.215452924564 (A)
# * Total L-BFGS iteration number: 412
#     Phi scaling constant:  243461.7231598273(A)
#     Final max constraint g violation(scaled): 4.381612628279186e-09
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 4.3381157315718214e-08
# * Last inner L_BFGS iteration number: 45
#     Inner convergence rate in x (scaled): 5.775447371739904e-11, 7.798177728084776e-11
#     Inner convergence rate in l: 4.4718007075061905e-11
#
# ----- Log barrier conversion -----
#     Objective of the final state:       1.0806511979912028
#     Objective after feasibility steps:  1.0863669899280275
#     Objective after the barrier method: 1.0832414506006058
#     Max violation of the final state:       4.381612628279186e-09
#     Max violation after feasibility steps:  -0.001860737405111168
#     Max violation after the barrier method: -0.0003116536341638554
# ***** Hessian matrix rank and cond: 1, 5.691670117131153e+19
# ***** Hessian matrix rank and cond: 1, 5.691670117131153e+19
# ***** Hessian matrix rank and cond: 1, 5.691670117131153e+19
# ***** Hessian matrix2 rank and cond: 2, 1.90056897892144e+17
# ***** Hessian matrix2 rank and cond: 2, 1.90056897892144e+17
# ***** Hessian matrix2 rank and cond: 2, 1.90056897892144e+17
# * Metric evaluated.
#     scaled x min, max = -1380.9665678480194, 9213.11321689147
#     f_B = 0.0010873066991038535
#     df_B/dy min, max: -0.008165961694624552, 0.9576920866966248
#     1st term (df_B/dx* dx*/dy) min, max: -0.9576920866966248, 0.22370452014566192
#     2nd term (df_B/dy) min, max:         -0.19294752596412815, 0.23359384743661854
#     dL_k/dy min, max:    -959600.5625, 224156.78378934108
#     d2L_k/dxdy min, max: -4715374045.483574, 125513660.71248993
#     VIHP min, max components (currently chosen): -4.50627024989799e-07, 2.3818748276375874e-08
# * Metric evaluated.
#     scaled x min, max = -1380.9665678480194, 9213.11321689147
#     f_max_Phi = 309948.53529074206
#     df_max_Phi/dy min, max: -1728352.375, 395736.6939479927
#     1st term (df_max_Phi/dx* dx*/dy) min, max: -395736.6939479927, 1728352.375
#     2nd term (df_max_Phi/dy) min, max:         0.0, 0.0
#     dL_k/dy min, max:    -959600.5625, 224156.78378934108
#     d2L_k/dxdy min, max: -4715374045.483574, 125513660.71248993
#     VIHP min, max components (currently chosen): -4.596721025192039, 4.356017037975857
# * Metric evaluated.
#     scaled x min, max = -1380.9665678480194, 9213.11321689147
#     f_K = 30386895925509.188
#     df_K/dy min, max: -624717086064640.0, 274617844460889.28
#     1st term (df_K/dx* dx*/dy) min, max: -275755240818428.97, 624717086064640.0
#     2nd term (df_K/dy) min, max:         -20437511350279.83, 52704582885415.81
#     dL_k/dy min, max:    -959600.5625, 224156.78378934108
#     d2L_k/dxdy min, max: -4715374045.483574, 125513660.71248993
#     VIHP min, max components (currently chosen): -23974276237.172424, 17530556500.635303
# time: 65.3088231086731
# Running QUADCOIL in verbose mode
#
# ----- Input summary -----
# Evaluation phi quadpoint num: 32
# Evaluation theta quadpoint num: 34
# Plasma phi quadpoint num: 32
# Plasma theta quadpoint num: 34
# Winding phi quadpoint num: 96
# Winding theta quadpoint num: 34
# Net poloidal current (A): 11884578.094260072
# Net toroidal current (A): 0.0
# Constraint names: ('f_B',)
# Constraint types: ('<=',)
# Constraint units: (Array(0.00108835, dtype=float32),)
# Constraint values: [0.00108835]
# Objective names: f_max_Phi2
# Objective units: 88738897920.0
# Objective weights: 1.0
# Numerical parameters:
#     {'c_growth_rate': Array(2, dtype=int64), 'c_init': Array(1., dtype=float64), 'ctol_outer': Array(1.e-08, dtype=float64), 'fstop_inner': Array(1.e-08, dtype=float64), 'fstop_inner_last': Array(0., dtype=float64), 'gtol_inner': Array(1.e-08, dtype=float64), 'gtol_inner_last': Array(1.e-10, dtype=float64), 'maxiter_inner': Array(1000, dtype=int64), 'maxiter_tot': Array(10000, dtype=int64), 'xstop_inner': Array(1.e-08, dtype=float64), 'xstop_inner_last': Array(1.e-10, dtype=float64), 'xstop_outer': Array(1.e-08, dtype=float64)}
# Plasma-coil distance (m): 0.1
# ----- DOF summary -----
# After converting non-smooth terms (such as |f|) into
# smooth terms, auxiliary vars and constraints, the dofs are:
#     phi_scaled: (312,)
#     scaled_max_phi_f_max_Phi2: (1,)
# Total # dofs (including auxiliary): 313
# Shape of mu, lam: (Array(1157, dtype=int64),), (Array(0, dtype=int64),)
# Total # of ineq constraint quantities (can have array output): 2
# Total # of eq constraint quantities (can have array output): 0
# Total # problem parameters: 191
# ----- Solver status summary -----
# Final value of f(scaled): 1.0620894530048628
# Final Max current potential (dipole density): 135627.4319840057 (A)
# Final Avg current potential (dipole density): 2734.1445572750017 (A)
# * Total L-BFGS iteration number: 410
#     Phi scaling constant:  241229.17926924676(A)
#     Final max constraint g violation(scaled): 8.489335900918604e-09
#     Final max constraint h violation(scaled): nan
#     Outer convergence rate in x (scaled): 2.3064853432229052e-08
# * Last inner L_BFGS iteration number: 42
#     Inner convergence rate in x (scaled): 8.780265443349937e-11, 1.1919539667534928e-10
#     Inner convergence rate in l: 1.7992940470890062e-11
# E0522 10:22:57.269585  815433 pjrt_stream_executor_client.cc:3045] Execution of replica 0 failed: INTERNAL: CustomCall failed: CpuCallback error: Traceback (most recent call last):
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/runpy.py", line 198, in _run_module_as_main
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/runpy.py", line 88, in _run_code
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel_launcher.py", line 18, in <module>
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 739, in start
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/tornado/platform/asyncio.py", line 205, in start
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/base_events.py", line 677, in run_forever
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/base_events.py", line 2034, in _run_once
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/events.py", line 89, in _run
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3098, in run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3153, in _run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3362, in run_cell_async
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3607, in run_ast_nodes
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3667, in run_code
#   File "/tmp/ipykernel_815433/2441185443.py", line 20, in <module>
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 340, in cache_miss
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 198, in _python_pjit_helper
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 1692, in _pjit_call_impl_python
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/profiler.py", line 333, in wrapper
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py", line 1289, in __call__
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/interpreters/mlir.py", line 2959, in _wrapped_callback
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[7], line 20
#      17 # Run QUADCOIL first
#      18 time1 = time.time()
# ---> 20 out_dict_i, qp_i, dofs_i, status_i = quadcoil(
#      21     nfp=plasma_surface.nfp,
#      22     stellsym=plasma_surface.stellsym,
#      23     plasma_coil_distance=separation,
#      24     mpol=mpol,
#      25     ntor=ntor,
#      26     plasma_dofs=plasma_dof_i,
#      27     plasma_mpol=plasma_surface.mpol,
#      28     plasma_ntor=plasma_surface.ntor,
#      29     net_poloidal_current_amperes=net_poloidal_current_amperes,
#      30     net_toroidal_current_amperes=0.,
#      31     metric_name=('f_max_Phi', 'f_K', 'f_B'),
#      32     objective_name='f_max_Phi2', # Minimizing peak dipole density
#      33     objective_unit=unit_Phi2, # under an f_B constraint
#      34     constraint_name=('f_B',),
#      35     constraint_type=('<=',),
#      36     constraint_unit=(f_B_target,),
#      37     constraint_value=np.array([f_B_target,]),
#      38     verbose=1,
#      39     # **numerical_kwargs
#      40 )
#      41 qp_list.append(qp_i)
#      42 block_until_ready(dofs_i)
#
#     [... skipping hidden 5 frame]
#
# File ~/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:1289, in ExecuteReplicated.__call__(self, *args)
#    1286 if (self.ordered_effects or self.has_unordered_effects
#    1287     or self.has_host_callbacks):
#    1288   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1289   results = self.xla_executable.execute_sharded(
#    1290       input_bufs, with_tokens=True
#    1291   )
#    1293   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1294       len(self.ordered_effects))
#    1295   sharded_runtime_token = results.consume_token()
#
# XlaRuntimeError: INTERNAL: CustomCall failed: CpuCallback error: Traceback (most recent call last):
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/runpy.py", line 198, in _run_module_as_main
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/runpy.py", line 88, in _run_code
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel_launcher.py", line 18, in <module>
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 739, in start
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/tornado/platform/asyncio.py", line 205, in start
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/base_events.py", line 677, in run_forever
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/base_events.py", line 2034, in _run_once
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/asyncio/events.py", line 89, in _run
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3098, in run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3153, in _run_cell
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3362, in run_cell_async
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3607, in run_ast_nodes
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3667, in run_code
#   File "/tmp/ipykernel_815433/2441185443.py", line 20, in <module>
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 340, in cache_miss
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 198, in _python_pjit_helper
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/pjit.py", line 1692, in _pjit_call_impl_python
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/profiler.py", line 333, in wrapper
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py", line 1289, in __call__
#   File "/home/lankef/.conda/envs/stellarator/lib/python3.13/site-packages/jax/_src/interpreters/mlir.py", line 2959, in _wrapped_callback
# KeyboardInterrupt:

# %%
plasma_dof_0_list = jnp.array(plasma_dof_0_list)
f_max_Phi_test_list = jnp.array(f_max_Phi_test_list)
f_max_Phi_diff_test_list = jnp.array(f_max_Phi_diff_test_list)
f_K_test_list = jnp.array(f_K_test_list)
f_B_test_list = jnp.array(f_B_test_list)
f_K_diff_test_list = jnp.array(f_K_diff_test_list)
time_quadcoil_list = jnp.array(time_quadcoil_list)
time_regcoil_list = jnp.array(time_regcoil_list)
lam_list = jnp.array(lam_list)
mu_list = jnp.linalg.norm(jnp.array(mu_list), axis=1)
c_list = jnp.array(c_list)

# %%
plt.plot(plasma_dof_0_list, f_K_test_list)

# %%
grad_f_max_Phi = jnp.gradient(f_max_Phi_test_list.flatten(), plasma_dof_0_list[1]-plasma_dof_0_list[0])
plt.plot(plasma_dof_0_list, grad_f_max_Phi, label='REGCOIL & numpy.gradient')
plt.scatter(plasma_dof_0_list, f_max_Phi_diff_test_list, label='QUADCOIL')
# plt.plot(plasma_dof_0_list, f_max_Phi_diff_test_list2, label='QUADCOIL2', linestyle='dashed')
plt.xlabel('$R_{00}$ of plasma surface')
plt.ylabel(r'$\partial \Phi_{max}/\partial R_{00}$ (K$^2$m$^2$)')
# plt.ylim(jnp.min(grad_f_max_Phi), jnp.max(grad_f_max_Phi))
plt.legend()
print('Max error:', jnp.max(jnp.abs(grad_f_max_Phi - f_max_Phi_diff_test_list)))
print('Avg error:', jnp.average(jnp.abs(grad_f_max_Phi - f_max_Phi_diff_test_list)))
# Out:
# Max error: 433573.51202274696
# Avg error: 366675.82866140676

# %%
grad_f_K = jnp.gradient(f_K_test_list.flatten(), plasma_dof_0_list[1]-plasma_dof_0_list[0])
plt.plot(plasma_dof_0_list, grad_f_K, label='REGCOIL & numpy.gradient')
plt.scatter(plasma_dof_0_list, f_K_diff_test_list, label='QUADCOIL')
# plt.plot(plasma_dof_0_list, f_K_diff_test_list2, label='QUADCOIL2', linestyle='dashed')
plt.xlabel('$R_{00}$ of plasma surface')
plt.ylabel(r'$\partial \Phi_{max}/\partial R_{00}$ (K$^2$m$^2$)')
# plt.ylim(jnp.min(grad_f_K), jnp.max(grad_f_K))
# plt.yscale('log')
plt.legend()
print('Max error:', jnp.max(jnp.abs(grad_f_K - f_K_diff_test_list)))
print('Avg error:', jnp.average(jnp.abs(grad_f_K - f_K_diff_test_list)))
# Out:
# Max error: 29809134329086.164
# Avg error: 8420932914229.229

# %%
jnp.save('breaking_params2', {
    'nfp': plasma_surface.nfp,
    'stellsym': plasma_surface.stellsym,
    'plasma_coil_distance': separation,
    'mpol': mpol,
    'ntor': ntor,
    'plasma_dofs': plasma_dof_i,
    'plasma_mpol': plasma_surface.mpol,
    'plasma_ntor': plasma_surface.ntor,
    'net_poloidal_current_amperes': net_poloidal_current_amperes,
    'net_toroidal_current_amperes': 0.,
    'metric_name': ('f_max_Phi', 'f_K', 'f_B'),
    'objective_name': 'f_max_Phi2', # Minimizing peak dipole density
    'objective_unit': unit_Phi2, # under an f_B constraint
    'constraint_name': ('f_B',),
    'constraint_type': ('<=',),
    'constraint_unit': (f_B_target,),
    'constraint_value': np.array([f_B_target,]),
    'verbose': 1
})
